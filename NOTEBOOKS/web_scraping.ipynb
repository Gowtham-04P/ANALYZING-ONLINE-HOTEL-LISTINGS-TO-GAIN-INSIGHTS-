# %%
import requests
from scrapy import Selector
from parsel import Selector
import pandas as pd
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup as bs

# %%
# Headers and URL set
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

# %%
agra= {
    'https://www.oyorooms.com/hotels-in-agra/?page=1',
    'https://www.oyorooms.com/hotels-in-agra/?page=2'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in agra:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'agra',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })
    else:
        print(f"Failed to fetch data from {url}, status code: {response.status_code}")

# Convert the list of dictionaries to a DataFrame
agra = pd.DataFrame(all_data)

# Display the DataFrame
agra
# Out:
#    Place                                         Hotel Name  \
# 0   agra                              Hotel O Sai President
# 1   agra                                   Hotel O ASA AGRA
# 2   agra        Hotel O Salt And Pepper Hotel And Resturant
# 3   agra                                Hotel O KING PALACE
# 4   agra                 Hotel O 804621 Hotel Vintage House
# 5   agra                               Hotel O Golden Grand
# 6   agra                                 Hotel O VK Palace
# 7   agra                         Super Capital O Taj Castle
# 8   agra                                Hotel O Grandfather
# 9   agra                         Hotel O KNIGHT IN HOMESTAY
# 10  agra              Hotel O R.K GUEST HOUSE & RESTAURANT
# 11  agra                            HOTEL O LAKSHYA PALACE
# 12  agra                       Hotel O Chaudhary Raj Hotal
# 13  agra                             Hotel O Taj Wonder Inn
# 14  agra                 Hotel O 7 STAR Hotel & Restaurant
# ...

# %%
response
# Out:
# <Response [200]>

# %%
ahmedabad= {
    'https://www.oyorooms.com/hotels-in-ahmedabad/?page=1',
    'https://www.oyorooms.com/hotels-in-ahmedabad/?page=2',
    'https://www.oyorooms.com/hotels-in-ahmedabad/?page=3',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ahmedabad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ahmedabad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ahmedabad = pd.DataFrame(all_data)

# Display the DataFrame
ahmedabad
# Out:
#         Place                                         Hotel Name  \
# 0   ahmedabad                                        Hotel O N Y
# 1   ahmedabad                                Hotel O Meet Palace
# 2   ahmedabad                                     Hotel O Apollo
# 3   ahmedabad                                Hotel O bhanu Villa
# 4   ahmedabad                                      Hotel O Malva
# 5   ahmedabad                                 Hotel O Dream Stay
# 6   ahmedabad                                 Hotel O Swagat Inn
# 7   ahmedabad                                    Hotel O Crystal
# 8   ahmedabad                                    Hotel O K Villa
# 9   ahmedabad              Palette River Front formerly Host Inn
# 10  ahmedabad                                  Hotel O Hill Park
# 11  ahmedabad                                 Hotel O Swagat Inn
# 12  ahmedabad                                 Hotel O Exotic Inn
# ...

# %%
ajmer= {
    'https://www.oyorooms.com/hotels-in-ajmer/',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ajmer:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ajmer',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ajmer = pd.DataFrame(all_data)

# Display the DataFrame
ajmer
# Out:
#     Place                                         Hotel Name  \
# 0   ajmer   Super Hotel O Ajmer Central formerly Grand Suman
# 1   ajmer            Hotel O Kesarganj formerly Suman Palace
# 2   ajmer  Collection O Beawer Road Ajmer formerly Hotel ...
# 3   ajmer      Collection O Ramganj formerly Hotel Gupta Inn
# 4   ajmer                    Hotel O Parao Formerly Cozy Inn
# 5   ajmer                        Super Hotel O Ganpati Plaza
# 6   ajmer                                   Hotel O Vaishali
# 7   ajmer                            Hotel O Pushkar Talhati
# 8   ajmer                             Hotel O Ajmer Heritage
# 9   ajmer                            Super Hotel O RMG Stays
# 10  ajmer                                Hotel O Goyal's Inn
# 11  ajmer                                  Hotel O Grand L M
#
#                                           Destination Actual Price  \
# 0                                  Gol Chakkar, Ajmer        ₹3890
# ...

# %%
aligarh= {
    'https://www.oyorooms.com/hotels-in-aligarh/?page=1',
    'https://www.oyorooms.com/hotels-in-aligarh/?page=2',
    'https://www.oyorooms.com/hotels-in-aligarh/?page=3',
        
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in aligarh:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'aligarh',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
aligarh = pd.DataFrame(all_data)

# Display the DataFrame
aligarh
# Out:
#       Place                                 Hotel Name  \
# 0   aligarh                      SPOT ON THE APPLE INN
# 1   aligarh                          SPOT ON Hotel GRH
# 2   aligarh                     Hotel O ARAVALI PALACE
# 3   aligarh              SPOT ON THE SWEET DREAM HOTEL
# 4   aligarh  Hotel O D.R. Hotel & Residency Restaurant
# 5   aligarh                           HOTEL O CLASSIC
# 6   aligarh                            HOTEL O RADHIKA
# 7   aligarh                       Hotel O Mohini Hotel
# 8   aligarh                              Hotel O R. S
# 9   aligarh   Hotel O C.P.S. HOTEL & FAMILY RESTAURANT
# 10  aligarh                   Hotel O Atithi Residency
# 11  aligarh                        SPOT ON GANGA HOTEL
# 12  aligarh                       Hotel O SAMRAT HOTEL
# 13  aligarh                       Hotel O RS RESIDENCY
# 14  aligarh                     Hotel O Royal Classic
# 15  aligarh                     OYO 90856 HOTEL MANNAT
# ...

# %%
alwar= {
    'https://www.oyorooms.com/hotels-in-alwar/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in alwar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'alwar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
alwar = pd.DataFrame(all_data)

# Display the DataFrame
alwar
# Out:
#     Place                                      Hotel Name  \
# 0   alwar                           Super Townhouse Alwar
# 1   alwar                        Hotel O White Rock Hotel
# 2   alwar                Super Hotel O Moti Doongri Alwar
# 3   alwar                      Hotel O New Paradise Hotel
# 4   alwar  Super Collection O Alwar formerly Hotel Ashoka
# 5   alwar                     Hotel O Ananda & Restaurant
# 6   alwar                      Hotel O Royal Galaxy Hotel
# 7   alwar                              Hotel O Vasu Hotel
# 8   alwar                 SPOT ON Riddhi Siddhi Residency
# 9   alwar                   Hotel O Alwar Hotel and Dhaba
# 10  alwar                       Hotel O Home Hotel Jalasa
# 11  alwar                          Hotel O Hotel Pushpraj
# 12  alwar                          Hotel O RED ROSE HOTEL
# 13  alwar                             Hotel O City Palace
#
#                                           Destination Actual Price  \
# ...

# %%
ambala= {
    'https://www.oyorooms.com/hotels-in-ambala/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ambala:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ambala',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ambala = pd.DataFrame(all_data)

# Display the DataFrame
ambala
# Out:
#     Place                 Hotel Name  \
# 0  ambala     Hotel O Welcome Lounge
# 1  ambala             Hotel O Heaven
# 2  ambala   Hotel O Dhruva Residency
# 3  ambala  Hotel O Angad Continental
# 4  ambala      Hotel O Sangam Resort
#
#                                          Destination Actual Price  \
# 0          Near Main Bus Stand, Ambala Cantt, Ambala        ₹3157
# 1                             Ambala Cantt. , Ambala        ₹2376
# 2                  Idgah road  Ambala Cantt., Ambala        ₹2979
# 3  At Main Bus Stand And Railway Station Ambala C...        ₹2630
# 4                  Near Suraj Kund Gurudwara, Ambala        ₹5091
#
#   Offer Percentage  Price        Ratings Review
# 0          68% off   ₹795  (259 Ratings)   Good
# 1          77% off   ₹434   (68 Ratings)   Fair
# 2          74% off   ₹614   (86 Ratings)   Fair
# 3          72% off   ₹583   (17 Ratings)   Fair
# 4          71% off  ₹1163    (8 Ratings)   Good

# %%
amritsar= {
    'https://www.oyorooms.com/hotels-in-amritsar/?page=1',
    'https://www.oyorooms.com/hotels-in-amritsar/?page=2',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in amritsar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'amritsar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
amritsar = pd.DataFrame(all_data)

# Display the DataFrame
amritsar
# Out:
#        Place                                     Hotel Name  \
# 0   amritsar                         Hotel O Mall Residency
# 1   amritsar                               Hotel O Axis Inn
# 2   amritsar                                   Hotel O Boss
# 3   amritsar                             Capital O City Inn
# 4   amritsar                        Hotel O Prince Paradise
# 5   amritsar                                     Hotel O TR
# 6   amritsar                        Hotel O Azaad Lifestyle
# 7   amritsar                         Hotel O Pink Residency
# 8   amritsar                                Hotel O Diamond
# 9   amritsar  Super Townhouse Ajit Nagar Near Golden Temple
# 10  amritsar     Super Collection O Amritsar Near Bus Stand
# 11  amritsar     Collection O Amritsar Near Railway Station
# 12  amritsar     Hotel O Heritage Street Near Golden Temple
# 13  amritsar                     Hotel O Saffron Night Stay
# 14  amritsar                       Super Hotel O Winner Inn
# ...

# %%
asansol= {
    'https://www.oyorooms.com/hotels-in-asansol/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in asansol:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'asansol',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
asansol = pd.DataFrame(all_data)

# Display the DataFrame
asansol
# Out:
#       Place                                     Hotel Name  \
# 0   asansol                           Hotel O Vatika Hotel
# 1   asansol                    Collection O Hindustan Vila
# 2   asansol                  Hotel O Prakash International
# 3   asansol                     Collection O Queens Resort
# 4   asansol                          Hotel O Shristi Lodge
# 5   asansol                           Collection O Flavour
# 6   asansol  Collection O Panorama Country Club And Resort
# 7   asansol         Super Collection O Meera International
# 8   asansol                           Hotel O ALISHA LODGE
# 9   asansol                               Hotel O AB Hotel
# 10  asansol                                 Hotel O Ajanta
#
#                                           Destination Actual Price  \
# 0             Near Debudi checkpost, Maithon, Asansol        ₹3688
# 1   D V C More Near Calcutta Girls High School, As...        ₹3939
# ...

# %%
aurangabad= {
    'https://www.oyorooms.com/hotels-in-aurangabad/?page=1',
    'https://www.oyorooms.com/hotels-in-aurangabad/?page=2',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in aurangabad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'aurangabad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
aurangabad = pd.DataFrame(all_data)

# Display the DataFrame
aurangabad
# Out:
#          Place                                    Hotel Name  \
# 0   aurangabad            Townhouse Kranti Square Aurangabad
# 1   aurangabad     Hotel O Bajaj Nagar Waluj formerly S Boss
# 2   aurangabad  Super Hotel O Padampura Near Railway Station
# 3   aurangabad              Hotel O Balaji Executive Lodging
# 4   aurangabad                        Hotel O Kohinoor Plaza
# 5   aurangabad                       Hotel O SHANGRILA ELITE
# 6   aurangabad                                Hotel O Chhaya
# 7   aurangabad                              Hotel O Carnival
# 8   aurangabad                  Hotel O Shree Balaji Lodging
# 9   aurangabad                             Hotel O Maharaja
# 10  aurangabad                       Hotel O Basuri Lodging
# 11  aurangabad                        Hotel O Vishwa Lodging
# 12  aurangabad              Hotel O 68179 Hotel New Abhijeet
# 13  aurangabad                       Hotel O Grand Executive
# ...

# %%
ayodhya= {
    'https://www.oyorooms.com/hotels-in-ayodhya/?page=1',
    'https://www.oyorooms.com/hotels-in-ayodhya/?page=2',
    'https://www.oyorooms.com/hotels-in-ayodhya/?page=3',
    'https://www.oyorooms.com/hotels-in-ayodhya/?page=4',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ayodhya:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ayodhya',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ayodhya = pd.DataFrame(all_data)

# Display the DataFrame
ayodhya
# Out:
#       Place                              Hotel Name  \
# 0   ayodhya   Hotel O Home Siya Bihari Guest House.
# 1   ayodhya              Hotel O Home Siya Homestay
# 2   ayodhya       Collection O Ayodhya Near Airport
# 3   ayodhya  Hotel O Home Mahadev Sadan Guest House
# 4   ayodhya               Hotel O Ramaland Homestay
# ..      ...                                     ...
# 67  ayodhya          Hotel O Prabhu Kripa Home Stay
# 68  ayodhya    Hotel O Home Shree Narayana Homestay
# 69  ayodhya           Hotel O Home Shankar Homestay
# 70  ayodhya                    Hotel O Crown Palace
# 71  ayodhya          OYO 820760 Hotel Balaji Palace
#
#                                           Destination Actual Price  \
# 0   Plot no-02 Raiganj Near Ayodhya Dham railway s...       ₹13071
# 1                                       Naka, Ayodhya       ₹13205
# 2   Near International Stadium, Prayagraj Road, Ay...           NA
# ...

# %%
bangalore= {
    'https://www.oyorooms.com/hotels-in-bangalore/?page=1',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=2',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=3',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=4',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=5',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=6',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=7',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=8',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=9',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=10',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=11',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=12',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=13',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=14',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=15',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=16',
    'https://www.oyorooms.com/hotels-in-bangalore/?page=17',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bangalore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bangalore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bangalore = pd.DataFrame(all_data)

# Display the DataFrame
bangalore
# Out:
#          Place                                         Hotel Name  \
# 0    bangalore                                 Hotel O U.G. Grand
# 1    bangalore          Super Townhouse Arekere Near Mithai Mahal
# 2    bangalore           Collection O Waiterly Boarding & Lodging
# 3    bangalore       Super Townhouse Bidadi formerly Royal Garuda
# 4    bangalore             Collection O Local Square | Whitefield
# ..         ...                                                ...
# 335  bangalore                             Hotel O Manu Residency
# 336  bangalore  Hotel O Champion Comfort Near Hosahalli Metro ...
# 337  bangalore                                  Hotel O Royal INN
# 338  bangalore                Hotel O Golden Inn Near Cubbon Park
# 339  bangalore                Hotel O Rajmahal Boarding & Lodging
#
#                                            Destination Actual Price  \
# 0                               Nagarbahavi, Bangalore        ₹2744
# ...

# %%
bareilly= {
    'https://www.oyorooms.com/hotels-in-bareilly/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bareilly:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bareilly',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bareilly = pd.DataFrame(all_data)

# Display the DataFrame
bareilly
# Out:
#       Place                                         Hotel Name  \
# 0  bareilly          Super Collection O Prabhat Nagar Bareilly
# 1  bareilly  Super Collection O Bareilly Near Satellite Bus...
# 2  bareilly  Super Collection O Civil Lines Near Old Bus St...
# 3  bareilly                                   Hotel O The Moon
# 4  bareilly                               Hotel O Amrit Palace
#
#                                 Destination Actual Price Offer Percentage  \
# 0    Opposite Kotak Mahindra Bank, Bareilly        ₹3934          67% off
# 1      Near Rohilkhand University, Bareilly        ₹5226          73% off
# 2  Near Old Roadways, Civil Lines, Bareilly        ₹5071          68% off
# 3                        Bareilly, Bareilly        ₹3379          73% off
# 4                        Bareilly, Bareilly        ₹3419          71% off
#
#    Price         Ratings     Review
# 0  ₹1072   (214 Ratings)  Excellent
# 1  ₹1193  (1536 Ratings)  Excellent
# ...

# %%
barpeta= {
    'https://www.oyorooms.com/hotels-in-barpeta/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in barpeta:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'barpeta',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
barpeta = pd.DataFrame(all_data)

# Display the DataFrame
barpeta
# Out:
#      Place                                  Hotel Name  \
# 0  barpeta                      Super Hotel O Axom Inn
# 1  barpeta  Hotel O WELCOME RESORT & FAMILY RESTAURANT
# 2  barpeta                              Hotel O Kriyan
# 3  barpeta                               Hotel O Mayur
# 4  barpeta             Hotel O ROYAL REGENCY, Pathsala
#
#                         Destination Actual Price Offer Percentage  Price  \
# 0                    Howly, Barpeta        ₹5561          68% off  ₹1422
# 1      BUILDING NO- 45null, Barpeta        ₹2493          76% off   ₹462
# 2                   Bajali, Barpeta        ₹3344          72% off   ₹760
# 3  Near Pathshala Bus Stop, Barpeta        ₹3344          72% off   ₹760
# 4                 Pathsala, Barpeta        ₹3028          71% off   ₹676
#
#          Ratings     Review
# 0  (641 Ratings)  Very Good
# 1  (109 Ratings)       Fair
# 2   (19 Ratings)       Good
# 3   (23 Ratings)  Very Good
# 4   (88 Ratings)       Good

# %%
bathinda= {
    'https://www.oyorooms.com/hotels-in-bathinda/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bathinda:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bathinda',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bathinda = pd.DataFrame(all_data)

# Display the DataFrame
bathinda
# Out:
#       Place                              Hotel Name  \
# 0  bathinda                         Hotel O Uman GG
# 1  bathinda                        Hotel O Green In
# 2  bathinda                         Hotel O Fridays
# 3  bathinda                              Hotel O ZR
# 4  bathinda                        Hotel O Hightown
# 5  bathinda             Hotel O King Star Residency
# 6  bathinda                      Hotel O Royal City
# 7  bathinda                     Hotel O Silver Star
# 8  bathinda  Hotel O Sui Generis Motel And Banquets
#
#                                    Destination Actual Price Offer Percentage  \
# 0                   Near Fouji Chowk, Bhatinda        ₹3321          72% off
# 1                   above Kotak Bank, Bathinda        ₹3674          71% off
# 2              G T Road Near Tinkoni, Bathinda        ₹2344          75% off
# 3    Back side Delhi heart institute, Bathinda        ₹2669          74% off
# ...

# %%
bawal= {
    'https://www.oyorooms.com/hotels-in-bawal/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bawal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bawal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bawal = pd.DataFrame(all_data)

# Display the DataFrame
bawal
# Out:
#    Place         Hotel Name  \
# 0  bawal  Hotel O Chaudhary
#
#                                          Destination Actual Price  \
# 0  v.p.o kotkasim th.kotkasim distic alwar Rajasthan        ₹2177
#
#   Offer Percentage Price       Ratings     Review
# 0          69% off  ₹541  (82 Ratings)  Excellent

# %%
berhampore= {
    'https://www.oyorooms.com/hotels-in-berhampore/',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in berhampore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'berhampore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
berhampore = pd.DataFrame(all_data)

# Display the DataFrame
berhampore
# Out:
#         Place                             Hotel Name  \
# 0  berhampore              Hotel O Taj International
# 1  berhampore            Silver Park Hotel And Dhaba
# 2  berhampore  Hotel O Mango Leaf Hotel & Restaurant
# 3  berhampore                 Hotel O JANGIPUR LODGE
# 4  berhampore                Hotel O New Hotel Mayur
# 5  berhampore                Super Hotel O ALO Hotel
# 6  berhampore  Hotel O Mohona Residency & Restaurant
# 7  berhampore                   Hotel O Subham Lodge
# 8  berhampore               Hotel O Roy Villa Resort
#
#                                         Destination Actual Price  \
# 0  Near Jolkol More, Kazi Nazrul Sarani, Berhampore        ₹2938
# 1                           Murshidabad, Berhampore        ₹3659
# 2                           Murshidabad, Berhampore        ₹2742
# 3                           Murshidabad, Berhampore        ₹3800
# 4             Near  Berhampore Bus Stop, Berhampore        ₹5234
# ...

# %%
bhilai= {
    'https://www.oyorooms.com/hotels-in-bhilai/?page=1',
    'https://www.oyorooms.com/hotels-in-bhilai/?page=2',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bhilai:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bhilai',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bhilai = pd.DataFrame(all_data)

# Display the DataFrame
bhilai
# Out:
#      Place                             Hotel Name  \
# 0   bhilai                          Hotel O River
# 1   bhilai                          Hotel O Kunal
# 2   bhilai                Hotel O New Happy Hours
# 3   bhilai                  Hotel O Dev Home Stay
# 4   bhilai      Palette - The Mark Club & Resorts
# 5   bhilai                       SPOT ON Krrish 2
# 6   bhilai          Super Hotel O Bhilai Near IIT
# 7   bhilai                   SPOT ON Hotel Krrish
# 8   bhilai                   Hotel O The Bell Oak
# 9   bhilai                          Hotel Jumanji
# 10  bhilai                SPOT ON Hotel Seema Inn
# 11  bhilai        Collection O Hotel Krrish Resto
# 12  bhilai  Super Hotel O Flagship Hotel Pragya 2
# 13  bhilai          SPOT ON 81062 Moonlight Hotel
# 14  bhilai                      Hotel O Blue Moon
# 15  bhilai                    Super Hotel O Manoj
# 16  bhilai               Super Hotel O Rewansh in
# 17  bhilai                        Hotel O Titanic
# ...

# %%
bhiwadi= {
    'https://www.oyorooms.com/hotels-in-bhiwadi/'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bhiwadi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bhiwadi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bhiwadi = pd.DataFrame(all_data)

# Display the DataFrame
bhiwadi
# Out:
#       Place                                 Hotel Name  \
# 0   bhiwadi        Super Hotel O Aravali Vihar Bhiwadi
# 1   bhiwadi                 Super Collection O Bhiwadi
# 2   bhiwadi                                   Townhall
# 3   bhiwadi              Hotel O R.K Bohra Guest House
# 4   bhiwadi           Hotel O Rajmahal Residency Hotel
# 5   bhiwadi                    Hotel O Chaudhary Hotel
# 6   bhiwadi                     Hotel O JR GUEST HOUSE
# 7   bhiwadi                          Hotel O Osaka Inn
# 8   bhiwadi                                 Hotel O KS
# 9   bhiwadi  Collection O The Grand Shalimar Residency
# 10  bhiwadi                       Hotel O SACHET HOTEL
# 11  bhiwadi                Hotel O Choudhary Residency
#
#                                           Destination Actual Price  \
# 0                                   Tapookra, Bhiwadi        ₹3129
# 1                          Near Capital Mall, Bhiwadi        ₹3158
# ...

# %%
bhubaneswar= {
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=1',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=2',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=3',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=4',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=5',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=6',
    'https://www.oyorooms.com/hotels-in-bhubaneswar/?page=7',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bhubaneswar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bhubaneswar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bhubaneswar = pd.DataFrame(all_data)

# Display the DataFrame
bhubaneswar
# Out:
#            Place                                     Hotel Name  \
# 0    bhubaneswar   Super Hotel O Patrapada Near DN Regalia Mall
# 1    bhubaneswar                           Hotel O Priya Palace
# 2    bhubaneswar  Super Townhouse Mancheswar Industrial Esatate
# 3    bhubaneswar         Super Townhouse Mancheswar Bhubaneswar
# 4    bhubaneswar                           Hotel O Dream Marion
# ..           ...                                            ...
# 135  bhubaneswar                Super Hotel O GAJAPATI PREMIUM
# 136  bhubaneswar                               Hotel O MS Plaza
# 137  bhubaneswar                     Collection O Secret Heaven
# 138  bhubaneswar                              SPOT ON M R Plaza
# 139  bhubaneswar                           Hotel O Sai Heritage
#
#                                            Destination Actual Price  \
# 0                              Khandagiri, Bhubaneswar        ₹3661
# ...

# %%
bhopal= {
    'https://www.oyorooms.com/hotels-in-bhopal/?page=1',
    'https://www.oyorooms.com/hotels-in-bhopal/?page=2',
    'https://www.oyorooms.com/hotels-in-bhopal/?page=3',
    'https://www.oyorooms.com/hotels-in-bhopal/?page=4',
    'https://www.oyorooms.com/hotels-in-bhopal/?page=5',
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bhopal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bhopal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bhopal = pd.DataFrame(all_data)

# Display the DataFrame
bhopal
# Out:
#      Place                   Hotel Name  \
# 0   bhopal  Hotel O Radha Madhav Palace
# 1   bhopal  Super Hotel O Mohit Regency
# 2   bhopal      Collection O Raj Regent
# 3   bhopal           Hotel O The Surbhi
# 4   bhopal       Super Zamzam Residency
# ..     ...                          ...
# 89  bhopal   Capital O Jd International
# 90  bhopal            Hotel O CHECK IN
# 91  bhopal      Collection O Udit Plaza
# 92  bhopal         Hotel O Palash House
# 93  bhopal            Hotel O Saket Inn
#
#                                           Destination Actual Price  \
# 0                                              BHOPAL        ₹2912
# 1              Near Hanuman Mandir, M P Nagar, Bhopal        ₹3644
# 2   40, Kundan Nagar,Bhel Sangam Chauraha,Near Dan...        ₹2695
# 3                                Huzur Tahsil, Bhopal        ₹3575
# 4   plot no 8plot no 8Royal Market infront of Taj-...        ₹4241
# ..                                                ...          ...
# ...

# %%
bijnor= {
    'https://www.oyorooms.com/hotels-in-bijnor/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bijnor:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bijnor',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bijnor = pd.DataFrame(all_data)

# Display the DataFrame
bijnor
# Out:
#     Place                                   Hotel Name  \
# 0  bijnor                   Hotel O SHARMA GUEST HOUSE
# 1  bijnor                Hotel O Shekhawat Guest House
# 2  bijnor             Hotel O 82972 Luxury Guest House
# 3  bijnor  SPOT ON Shiva Family Restaurant Guest House
# 4  bijnor                SPOT ON ROYAL BLUE MOON HOTEL
# 5  bijnor                   Hotel O Luxury Guest house
#
#                                          Destination Actual Price  \
# 0                             SEOHARA BIJNOR, Bijnor        ₹3339
# 1              plot-12 Shekhawat Guest House, Bijnor        ₹2669
# 2                                     Bijnor, Bijnor        ₹2422
# 3                       Near Janta Hospital , Bijnor           NA
# 4                                 Bakshiwala, Bijnor           NA
# 5  Near _ HP petrol pump Seohara road dhampur, Bi...           NA
#
#   Offer Percentage Price       Ratings     Review
# 0          72% off  ₹755  (56 Ratings)       Good
# ...

# %%
bilaspur= {
    'https://www.oyorooms.com/hotels-in-bilaspur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bilaspur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bilaspur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bilaspur = pd.DataFrame(all_data)

# Display the DataFrame
bilaspur
# Out:
#       Place                  Hotel Name  \
# 0  bilaspur            Hotel O Bilaspur
# 1  bilaspur              Hotel O Amaira
# 2  bilaspur        Collection O Suvidha
# 3  bilaspur         Hotel O Golden Leaf
# 4  bilaspur               Hotel O Divya
# 5  bilaspur  Hotel O Vijaya Guest House
# 6  bilaspur           Hotel O Shivam In
# 7  bilaspur         Hotel O KVR snuggle
#
#                                          Destination Actual Price  \
# 0                     Near Apollo Hospital, Bilaspur        ₹3705
# 1                            Ratanpur Road, Bilaspur        ₹3048
# 2         Near Gole Bazar, Gole Bazar Road, Bilaspur        ₹4382
# 3        Near Apollo Hospital, Seepat Road, Bilaspur        ₹2822
# 4                                 Sarkanda, Bilaspur        ₹2671
# 5  Plot No. 01 Khamatarai Road In Front Off Bank ...        ₹2774
# 6                                    Torba, Bilaspur        ₹2771
# 7                               Deorikhurd, Bilaspur        ₹2458
#
# ...

# %%
bodhgaya= {
    'https://www.oyorooms.com/hotels-in-bodhgaya/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bodhgaya:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bodhgaya',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bodhgaya = pd.DataFrame(all_data)

# Display the DataFrame
bodhgaya
# Out:
#       Place                                         Hotel Name  \
# 0  bodhgaya     Super Hotel O Gol Bagicha Near Railway Station
# 1  bodhgaya                      Hotel O Shiv guru guest house
# 2  bodhgaya  Super Hotel O Bodh Gaya Near Nigma Monastery F...
# 3  bodhgaya                               Super Hotel O Shivam
# 4  bodhgaya                          Hotel O Aryan Guest House
# 5  bodhgaya                                    Hotel O Embassy
# 6  bodhgaya                          Hotel O PUNAM GUEST HOUSE
# 7  bodhgaya                       Hotel O Kanako International
# 8  bodhgaya                          Hotel O C K International
#
#                                         Destination Actual Price  \
# 0  Near Shree Ram Tilkut Bhandar, Tekari Road, Gaya        ₹3952
# 1                  Near Karmapa Monastery, Bodhgaya        ₹3494
# 2                   Near Nigma Monastery, Bodh Gaya        ₹4479
# 3                              Dayal Kunj, Bodhgaya        ₹3834
# ...

# %%
bulandshahr= {
    'https://www.oyorooms.com/hotels-in-bulandshahr/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in bulandshahr:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'bulandshahr',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
bulandshahr = pd.DataFrame(all_data)

# Display the DataFrame
bulandshahr
# Out:
#           Place                                 Hotel Name  \
# 0   bulandshahr                           HOTEL TOWN HOUSE
# 1   bulandshahr                  Hotel O POP Hotel Highway
# 2   bulandshahr                        SPOT ON HOTEL GRAND
# 3   bulandshahr                    Hotel O The Crown Plaza
# 4   bulandshahr                       Hotel O Royal Palace
# 5   bulandshahr                             Spot On T Town
# 6   bulandshahr            Hotel O Sparrow House Residency
# 7   bulandshahr                              Hotel O Super
# 8   bulandshahr           Hotel O MOONLIGHT HOTEL & RESTRO
# 9   bulandshahr         SPOT ON AMS SHINE Hotel And Restro
# 10  bulandshahr                        SPOT ON HOTEL ROMAN
# 11  bulandshahr                          Hotel O Midtown 1
# 12  bulandshahr                             Hotel O Galaxy
# 13  bulandshahr                Hotel O Relax Inn Residency
# 14  bulandshahr                       SPOT ON ROCK STAR II
# ...

# %%
calicut= {
    'https://www.oyorooms.com/hotels-in-calicut/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in calicut:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'calicut',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
calicut = pd.DataFrame(all_data)

# Display the DataFrame
calicut
# Out:
#       Place                                    Hotel Name  \
# 0   calicut  Super Hotel O West Hill near Mietra Hospital
# 1   calicut    Super Hotel O Kunnamangalam Near Bus Stand
# 2   calicut                       Hotel O Olive Residency
# 3   calicut                       Hotel O A One Residency
# 4   calicut                        Hotel O  Scott Legacy
# 5   calicut                   Townhouse OAK Central Suits
# 6   calicut                   Collection O EXPRESS SUITES
# 7   calicut                            Hotel O river view
# 8   calicut                              Hotel O Stay Inn
# 9   calicut             Collection O Marhaba Govindapuram
# 10  calicut                           Hotel O Madhurapuri
# 11  calicut                        Palette - Fezinn Hotel
# 12  calicut                               Hotel O DELAMAR
# 13  calicut                      Hotel O My Global Wander
#
#                                         Destination Actual Price  \
# ...

# %%
chandigarh= {
    'https://www.oyorooms.com/hotels-in-chandigarh/?page=1',
    'https://www.oyorooms.com/hotels-in-chandigarh/?page=2',
    'https://www.oyorooms.com/hotels-in-chandigarh/?page=3',
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in chandigarh:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'chandigarh',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
chandigarh = pd.DataFrame(all_data)

# Display the DataFrame
chandigarh
# Out:
#          Place                                         Hotel Name  \
# 0   chandigarh                                     Hotel O Prince
# 1   chandigarh                            Hotel O Karan Residency
# 2   chandigarh                                Collection O Athens
# 3   chandigarh                                   Hotel O The Eden
# 4   chandigarh                     Collection O Hotel North East
# 5   chandigarh                          Collection O Red Paradise
# 6   chandigarh                                   Hotel O Citywalk
# 7   chandigarh                          Hotel O Royal Crown Erica
# 8   chandigarh                            Hotel O GLASS INN HOTEL
# 9   chandigarh                               Hotel O GG RESIDENCY
# 10  chandigarh                                     Hotel O Simran
# 11  chandigarh        Hotel O Royal Zirakpur Formerly Royal woods
# 12  chandigarh                                Hotel O Sun City 42
# ...

# %%
chennai= {
    'https://www.oyorooms.com/hotels-in-chennai/?page=1',
    'https://www.oyorooms.com/hotels-in-chennai/?page=2',
    'https://www.oyorooms.com/hotels-in-chennai/?page=3',
    'https://www.oyorooms.com/hotels-in-chennai/?page=4',
    'https://www.oyorooms.com/hotels-in-chennai/?page=5',
    'https://www.oyorooms.com/hotels-in-chennai/?page=6',
    'https://www.oyorooms.com/hotels-in-chennai/?page=7'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in chennai:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'chennai',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
chennai = pd.DataFrame(all_data)

# Display the DataFrame
chennai
# Out:
#        Place                                         Hotel Name  \
# 0    chennai     Super Hotel O Triplicane formerly Park Royal
# 1    chennai                        Hotel O Karapakkam, Chennai
# 2    chennai  Hotel O Home G-cloud Near Thirumangalam Metro ...
# 3    chennai                                 Hotel O MIZPAH INN
# 4    chennai                            Hotel O The prince Park
# ..       ...                                                ...
# 135  chennai  SPOT ON The Grand Guest House Near PVR Cinemas...
# 136  chennai     Hotel O Harma Residency Near Jazz Cinemas Luxe
# 137  chennai                               Hotel O JP Residency
# 138  chennai                          Hotel O Dakshin Villa ECR
# 139  chennai          Super Hotel O Chrompet Near Rela Hospital
#
#                                          Destination Actual Price  \
# 0                                Triplicane, Chennai        ₹8505
# ...

# %%
coimbatore= {
    'https://www.oyorooms.com/hotels-in-coimbatore/?page=1',
    'https://www.oyorooms.com/hotels-in-coimbatore/?page=2',
    'https://www.oyorooms.com/hotels-in-coimbatore/?page=3'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in coimbatore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'coimbatore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
coimbatore = pd.DataFrame(all_data)

# Display the DataFrame
coimbatore
# Out:
#          Place                                         Hotel Name  \
# 0   coimbatore                           Hotel O DSR AVENUE ROOMS
# 1   coimbatore                              Hotel O A K residency
# 2   coimbatore                             Hotel O VIRKSHAM HOTEL
# 3   coimbatore                              SPOT ON Thangam Lodge
# 4   coimbatore                        Hotel O Maruthi Gandhi Park
# 5   coimbatore                                 Hotel O Kota Lodge
# 6   coimbatore                        Super Townhouse Four Season
# 7   coimbatore                          Hotel O Magical Crown Inn
# 8   coimbatore                         Hotel O Aruthraa Residency
# 9   coimbatore                             Townhouse Sundarapuram
# 10  coimbatore               Collection O Skry Hotels Gandhipuram
# 11  coimbatore                                Hotel O EMERALD INN
# 12  coimbatore                                  Hotel O SMS HOMES
# ...

# %%
coorg= {
    'https://www.oyorooms.com/hotels-in-coorg/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in coorg:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'coorg',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
coorg = pd.DataFrame(all_data)

# Display the DataFrame
coorg
# Out:
#    Place                                         Hotel Name  \
# 0  coorg  Super Collection O Kushal Nagar Near KSRTC Bus...
# 1  coorg                                 Collection O Coorg
# 2  coorg  Super Collection O Virajpet City Centre former...
# 3  coorg  Super Collection O Madikeri City Center Near K...
# 4  coorg         Townhouse Madikeri Fort formerly Hotel Raj
# 5  coorg  Townhouse Oak Kushal Nagar formerly Paddington...
#
#                                     Destination Actual Price Offer Percentage  \
# 0                          Kushalnagara, Coorg.        ₹3789          74% off
# 1          Near Dubare Road, Kushalnagar, Coorg        ₹4663          74% off
# 2                               Virajpet, Coorg        ₹4523          73% off
# 3           Near Hotel Raj, College Road, Coorg        ₹5218          68% off
# 4    Near Cauvery Hall, Race Course Road, Coorg        ₹3814          71% off
# ...

# %%
cuttack= {
    'https://www.oyorooms.com/hotels-in-cuttack/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in cuttack:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'cuttack',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
cuttack = pd.DataFrame(all_data)

# Display the DataFrame
cuttack
# Out:
#       Place                                   Hotel Name  \
# 0   cuttack                          Flagship Dream Stay
# 1   cuttack               Hotel O MAA BHUASUNI RESIDENCY
# 2   cuttack                 SPOT ON Prabir Residency Inn
# 3   cuttack                          Hotel O M Residency
# 4   cuttack                         Hotel O Heritage Inn
# 5   cuttack                         Hotel O Bikram Lodge
# 6   cuttack                          Hotel O Cuttack inn
# 7   cuttack                             Hotel O M Palace
# 8   cuttack              Hotel O New Cuttack Guest House
# 9   cuttack  Hotel O Flagship 81132 Hotel Chandia Palace
# 10  cuttack                    Hotel O Sun Perfect Lodge
# 11  cuttack                      Hotel O Siddharth Hotel
# 12  cuttack            Hotel O  swayamsiddha continental
# 13  cuttack                  Hotel O Shree Ram Residency
# 14  cuttack                        Capital O Jai Adisson
# ...

# %%
dehradun= {
    'https://www.oyorooms.com/hotels-in-dehradun/?page=1',
    'https://www.oyorooms.com/hotels-in-dehradun/?page=2',
    'https://www.oyorooms.com/hotels-in-dehradun/?page=3',
    'https://www.oyorooms.com/hotels-in-dehradun/?page=4'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in dehradun:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'dehradun',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
dehradun = pd.DataFrame(all_data)

# Display the DataFrame
dehradun
# Out:
#        Place                            Hotel Name  \
# 0   dehradun           SPOT ON Chandra's Residence
# 1   dehradun                   SPOT ON Second Home
# 2   dehradun               Hotel O Khalsa Homestay
# 3   dehradun               SPOT ON Sneha Home Stay
# 4   dehradun  Super Collection O The Kailash Hotel
# ..       ...                                   ...
# 75  dehradun                    Hotel O Lime Wood
# 76  dehradun           Hotel O Vithalesh Home Stay
# 77  dehradun        Hotel O Ganga PG And Home Stay
# 78  dehradun          Hotel O Home Gautam Homestay
# 79  dehradun          SPOT ON Shri Ram Guest House
#
#                                           Destination Actual Price  \
# 0                  Near Jolly Grant Airport, Dehradun        ₹2412
# 1                                 Premnagar, Dehradun        ₹2184
# 2                        Chander Lok Colony, Dehradun        ₹3761
# 3   Inside the lane beside Gurudwara & Uttaranchal...        ₹2429
# ...

# %%
delhi= {
    'https://www.oyorooms.com/hotels-in-delhi/?page=1',
    'https://www.oyorooms.com/hotels-in-delhi/?page=2',
    'https://www.oyorooms.com/hotels-in-delhi/?page=3',
    'https://www.oyorooms.com/hotels-in-delhi/?page=4',
    'https://www.oyorooms.com/hotels-in-delhi/?page=5',
    'https://www.oyorooms.com/hotels-in-delhi/?page=6',
    'https://www.oyorooms.com/hotels-in-delhi/?page=7',
    'https://www.oyorooms.com/hotels-in-delhi/?page=8',
    'https://www.oyorooms.com/hotels-in-delhi/?page=9',
    'https://www.oyorooms.com/hotels-in-delhi/?page=10',
    'https://www.oyorooms.com/hotels-in-delhi/?page=11',
    'https://www.oyorooms.com/hotels-in-delhi/?page=12',
    'https://www.oyorooms.com/hotels-in-delhi/?page=13',
    'https://www.oyorooms.com/hotels-in-delhi/?page=14'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in delhi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'delhi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
delhi = pd.DataFrame(all_data)

# Display the DataFrame
delhi
# Out:
#      Place                                     Hotel Name  \
# 0    delhi                           Hotel O Mayur Palace
# 1    delhi  Super Collection O Palam Near Railway Station
# 2    delhi              Hotel O Premium Rooms Chhatarpur
# 3    delhi                        Hotel O D.C GUEST HOUSE
# 4    delhi                    Hotel O Kaushik Guest House
# ..     ...                                            ...
# 275  delhi                 Hotel O One plus One residency
# 276  delhi                      Hotel O South Plaza (B&B)
# 277  delhi                   Townhouse OAK Hotel C Pearls
# 278  delhi                          Hotel O Sushma Ssadan
# 279  delhi            Hotel The Arrow Near Paschim Vihar
#
#                                            Destination Actual Price  \
# 0             Near Shraddhanand College, Alipur, Delhi        ₹3164
# 1                Near New Prakash Watch Company, Delhi        ₹6589
# ...

# %%
delhi_transit= {
    'https://www.oyorooms.com/hotels-in-delhi_transit/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in delhi_transit:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'delhi_transit',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
delhi_transit = pd.DataFrame(all_data)

# Display the DataFrame
delhi_transit
# Out:
#             Place                                         Hotel Name  \
# 0   delhi_transit                        Hotel O Rangpuri Mahipalpur
# 1   delhi_transit                                   Hotel O Kohinoor
# 2   delhi_transit  Collection O Mahipalpur near Airport formerly ...
# 3   delhi_transit                                     Hotel O Aamara
# 4   delhi_transit                                      Hotel O Glace
# 5   delhi_transit                     Hotel O INTERNATIONAL EMBASSY
# 6   delhi_transit                                Hotel O Shanti Stay
# 7   delhi_transit                                 Hotel O Global Inn
# 8   delhi_transit                            Hotel O Krishna Cottage
# 9   delhi_transit                             Hotel O Dynasty Suites
# 10  delhi_transit  Collection O Mahipalpur Road No 4 Formerly Hot...
# 11  delhi_transit                            Hotel O The Glory Hotel
# 12  delhi_transit                                Hotel O  Alpha Stay
# ...

# %%
deoghar= {
    'https://www.oyorooms.com/hotels-in-deoghar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in deoghar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'deoghar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
deoghar = pd.DataFrame(all_data)

# Display the DataFrame
deoghar
# Out:
#       Place                                         Hotel Name  \
# 0   deoghar  Hotel O 819125 HOTEL SHIV TRIPTI AND BANQUET HALL
# 1   deoghar                               SPOT ON Hotel  Sagar
# 2   deoghar                        SPOT ON Gajadhar Rest House
# 3   deoghar                                     Hotel O Ambika
# 4   deoghar                                   Hotel O Shivdham
# 5   deoghar                       Palette Hotel Relax, Deoghar
# 6   deoghar                              Super Hotel O Parinay
# 7   deoghar          OYO 824156 HOTEL OM PALACE & BANQUET HALL
# 8   deoghar                         Hotel O New Maa Tara Hotel
# 9   deoghar                         Hotel O Shivaye Rest House
# 10  deoghar                                      Hotel O Saalt
#
#                                  Destination Actual Price Offer Percentage  \
# 0         Beside Mangala Pokharnull, Deoghar        ₹6066          83% off
# ...

# %%
dhanbad= {
    'https://www.oyorooms.com/hotels-in-dhanbad/?page=1',
    'https://www.oyorooms.com/hotels-in-dhanbad/?page=2'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in dhanbad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'dhanbad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
dhanbad = pd.DataFrame(all_data)

# Display the DataFrame
dhanbad
# Out:
#       Place                                         Hotel Name  \
# 0   dhanbad                           Hotel O Raj Munmun Hotel
# 1   dhanbad                      Hotel O VNR Hotel And Resort
# 2   dhanbad          Super Hotel O Bhagmati Garden Guest House
# 3   dhanbad                          Hotel O Anandam Residency
# 4   dhanbad           Super Capital O Gulmohar Marriage Garden
# 5   dhanbad  Super Townhouse Oak Dhanbad Near SSLNT College...
# 6   dhanbad                              Super Hotel O A Hotel
# 7   dhanbad  Townhouse Bank More Dhanbad Formerly Rise And ...
# 8   dhanbad                            Hotel O 27 Degree Hotel
# 9   dhanbad                                Hotel O Bridge View
# 10  dhanbad                         Super Hotel O CITY HEIGHTS
# 11  dhanbad                            Super Hotel O Grill Inn
# 12  dhanbad                            Collection O DIVIRA INN
# 13  dhanbad                        Super Hotel O Sofitel Hotel
# ...

# %%
dharamshala= {
    'https://www.oyorooms.com/hotels-in-dharamshala/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in dharamshala:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'dharamshala',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
dharamshala = pd.DataFrame(all_data)

# Display the DataFrame
dharamshala
# Out:
#          Place                                         Hotel Name  \
# 0  dharamshala  Super Townhouse Oak Dharamshala Near Maximus Mall
# 1  dharamshala  Super Hotel O Civil Lines Dharamshala formerly...
# 2  dharamshala                        Super Townhouse Dharamshala
# 3  dharamshala                   Townhouse Dhauladhar Nature Park
# 4  dharamshala                            Hotel O The Rana Palace
# 5  dharamshala                        Hotel O Asian Resorts N Spa
# 6  dharamshala                              Hotel O Country Lodge
# 7  dharamshala                         Hotel O Sun shine homestay
#
#                                          Destination Actual Price  \
# 0           Near Maximus Mall, Chilgari, Dharamshala        ₹6378
# 1           Near KCC Bank, College Road, Dharamshala        ₹4837
# 2  Near Housing Board Colony, Khanyara Road, Dhar...        ₹4679
# 3  Near Dhauladhar National Park, Lambapat, Dhara...        ₹3366
# ...

# %%
digha= {
    'https://www.oyorooms.com/hotels-in-digha/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in digha:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'digha',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
digha = pd.DataFrame(all_data)

# Display the DataFrame
digha
# Out:
#     Place                                   Hotel Name  \
# 0   digha                      Super Capital O Bidisha
# 1   digha                      Hotel O MAITY RESIDENCY
# 2   digha                     Hotel O Prantika Banquet
# 3   digha               Collection O Resort K Sea View
# 4   digha                             Hotel O Sonamoni
# 5   digha                            Hotel O Debopriya
# 6   digha                    Collection O PRINCE PLAZA
# 7   digha                  Hotel O Kohinur Guest House
# 8   digha                     Hotel O SANKHADHWANI INN
# 9   digha                              Hotel O Ashiqui
# 10  digha                       Palette - Daltin Tower
# 11  digha  Townhouse The Grand Touch & The Royal Touch
# 12  digha    Hotel O Homestay Unique Beach Guest House
# 13  digha                            Hotel O SEA FEVER
# 14  digha                         Hotel O Golden Queen
#
#                                           Destination Actual Price  \
# ...

# %%
durgapur= {
    'https://www.oyorooms.com/hotels-in-durgapur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in durgapur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'durgapur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
durgapur = pd.DataFrame(all_data)

# Display the DataFrame
durgapur
# Out:
#       Place                   Hotel Name  \
# 0  durgapur  Hotel O Urvashi Guest House
# 1  durgapur      Super Hotel O Nandi Inn
# 2  durgapur           Hotel O Blue Amber
# 3  durgapur     Super Hotel O A.R. Lodge
#
#                                          Destination Actual Price  \
# 0  Mnav 16 Mnav 16 Bengal Ambuja Housing Complex,...        ₹4028
# 1    Near Bus Stop, Muchipada Shibbur Road, Durgapur        ₹4125
# 2                     Near Reliance Trends, Durgapur        ₹4149
# 3                              Bidhannagar, Durgapur           NA
#
#   Offer Percentage  Price        Ratings     Review
# 0          67% off  ₹1051   (98 Ratings)       Good
# 1          76% off   ₹753  (335 Ratings)  Excellent
# 2          75% off   ₹828   (59 Ratings)       Good
# 3               NA     NA  (275 Ratings)  Very Good

# %%
ernakulam= {
    'https://www.oyorooms.com/hotels-in-ernakulam/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ernakulam:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ernakulam',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ernakulam = pd.DataFrame(all_data)

# Display the DataFrame
ernakulam
# Out:
#        Place                               Hotel Name  \
# 0  ernakulam  Super Hotel O Vennala Near Palarivattom
# 1  ernakulam                    Capital O Rayan Plaza
# 2  ernakulam                       Hotel O SREEMAGAM
# 3  ernakulam                     SPOT ON Riyan Suites
#
#                                          Destination Actual Price  \
# 0                            Palarivattom, Ernakulam        ₹4800
# 1  Near Nalanda School, Thammanam- Vytilla road, ...        ₹3604
# 2                                  Kerala, Ernakulam        ₹3419
# 3                              Kuthappady, Ernakulam        ₹3251
#
#   Offer Percentage  Price        Ratings     Review
# 0          72% off  ₹1110  (277 Ratings)  Very Good
# 1          72% off   ₹818  (131 Ratings)       Fair
# 2          71% off   ₹779    (1 Ratings)   Fabulous
# 3          72% off   ₹738  (114 Ratings)       Fair

# %%
erode= {
    'https://www.oyorooms.com/hotels-in-erode/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in erode:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'erode',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
erode = pd.DataFrame(all_data)

# Display the DataFrame
erode
# Out:
#    Place                             Hotel Name  \
# 0  erode          Super Hotel O Erode Bus Stand
# 1  erode  Super Hotel O Chinnamuthu Main Street
# 2  erode                 Hotel O Saravana Stays
# 3  erode               Super Hotel O City Lodge
# 4  erode                   Hotel O Sakthi Grand
# 5  erode        Hotel O Mermaid's Le Castle Inn
#
#                          Destination Actual Price Offer Percentage  Price  \
# 0           Near Kalyan Silks, Erode        ₹3701          71% off   ₹860
# 1           Edayankattuvalasu, Erode        ₹3943          80% off   ₹617
# 2  Near Kavindapadi Bus Stand, Erode        ₹2315          76% off   ₹419
# 3                       India, Erode        ₹2868          72% off   ₹647
# 4  Near GH Circle, Erode Fort, Erode        ₹4172          67% off  ₹1099
# 5                  Perundurai, Erode        ₹5344          68% off  ₹1378
#
#          Ratings     Review
# 0   (38 Ratings)  Very Good
# 1  (623 Ratings)  Excellent
# ...

# %%
faridaba= {
    'https://www.oyorooms.com/hotels-in-faridabad/?page=1',
    'https://www.oyorooms.com/hotels-in-faridabad/?page=2',
    'https://www.oyorooms.com/hotels-in-faridabad/?page=3'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in faridaba:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'faridaba',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
faridaba = pd.DataFrame(all_data)

# Display the DataFrame
faridaba
# Out:
#        Place                             Hotel Name  \
# 0   faridaba               Hotel O Skyway Residency
# 1   faridaba                       Hotel The mannat
# 2   faridaba                         Hotel O Lavish
# 3   faridaba                      Hotel O Sky High
# 4   faridaba                       Hotel O Lakeview
# 5   faridaba    Hotel O Krishna Hotel & Guest House
# 6   faridaba                      Hotel O Evergreen
# 7   faridaba               Hotel O Country Homestay
# 8   faridaba                      Hotel O Royal Inn
# 9   faridaba                    Townhouse Surajkund
# 10  faridaba                      Hotel O Aroma Inn
# 11  faridaba                      Hotel O Red Crown
# 12  faridaba                         Hotel O Galaxy
# 13  faridaba                   Hotel O Glory Galaxy
# 14  faridaba               SPOT ON Hotel Green City
# 15  faridaba                    Hotel O Maira Homes
# 16  faridaba                 Hotel O Sewa Residency
# ...

# %%
gangtok= {
    'https://www.oyorooms.com/hotels-in-gangtok/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gangtok:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gangtok',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gangtok = pd.DataFrame(all_data)

# Display the DataFrame
gangtok
# Out:
#       Place                      Hotel Name  \
# 0   gangtok      Townhouse Mansarovar Hotel
# 1   gangtok               Hotel O Green Dot
# 2   gangtok              Hotel O Ridge Park
# 3   gangtok       Hotel O Nourpem Residency
# 4   gangtok        Hotel O Himalaya Gangtok
# 5   gangtok  Collection O NORBULING RETREAT
# 6   gangtok     Hotel O Basar International
# 7   gangtok   Hotel O 35610 Hotel SHAYABONG
# 8   gangtok               Hotel O Demadzong
# 9   gangtok                  Hotel O Betila
# 10  gangtok     Hotel O Central Hill Resort
#
#                                           Destination Actual Price  \
# 0          Gangtok Singtam - Chungthang Road, Gangtok        ₹3248
# 1                  Near GuruDhuwara, Deorali, Gangtok        ₹6499
# 2                            Near White Hall, Gangtok        ₹4221
# 3                      Near Development Area, Gangtok        ₹3166
# 4                           Tathangchen Area, Gangtok        ₹6691
# ...

# %%
gaya= {
    'https://www.oyorooms.com/hotels-in-gaya/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gaya:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gaya',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gaya = pd.DataFrame(all_data)

# Display the DataFrame
gaya
# Out:
#   Place                          Hotel Name  \
# 0  gaya  Hotel O HAPPY PLACE HOTEL & RESORT
# 1  gaya          Hotel O Family Guest House
# 2  gaya              Hotel O Divisha palace
# 3  gaya          Hotel O Magadh Guest House
# 4  gaya   Hotel O The House Of Kanha Resort
#
#                           Destination Actual Price Offer Percentage  Price  \
# 0  Bhindas Wazirganj Gaya Bihar, Gaya        ₹3242          71% off   ₹736
# 1                         Bihar, Gaya        ₹3634          71% off   ₹829
# 2                        MANPUR, Gaya        ₹3276          73% off   ₹710
# 3                 Road Number 7, Gaya        ₹4811          72% off  ₹1100
# 4                          Gaya, Gaya        ₹3659          71% off   ₹835
#
#          Ratings     Review
# 0   (10 Ratings)  Excellent
# 1   (22 Ratings)  Excellent
# 2   (10 Ratings)  Excellent
# 3  (162 Ratings)  Very Good
# 4    (2 Ratings)   Fabulous

# %%
ghaziabad= {
    'https://www.oyorooms.com/hotels-in-ghaziabad/?page=3',
    'https://www.oyorooms.com/hotels-in-ghaziabad/?page=2',
    'https://www.oyorooms.com/hotels-in-ghaziabad/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ghaziabad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ghaziabad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ghaziabad = pd.DataFrame(all_data)

# Display the DataFrame
ghaziabad
# Out:
#         Place                                         Hotel Name  \
# 0   ghaziabad                          Hotel O Red Diamond Hotel
# 1   ghaziabad                                   Hotel O Crewford
# 2   ghaziabad  Townhouse Townhouse Atal Chowk Indirapuram Gha...
# 3   ghaziabad                  Hotel O Royal vaid G Guest House
# 4   ghaziabad                                    Hotel O Rosella
# 5   ghaziabad                                        Hotel O A.S
# 6   ghaziabad                                Hotel O Crystal Inn
# 7   ghaziabad                            Hotel O Kwins Residency
# 8   ghaziabad                       Hotel O Welcome Guest House
# 9   ghaziabad                                 Hotel O Blue Moon
# 10  ghaziabad                                  Hotel O Metro Inn
# 11  ghaziabad                Townhouse Siddharth Vihar Ghaziabad
# 12  ghaziabad             TOWNHOUSE THE HOTEL DIAMOND VASUNDHARA
# ...

# %%
goa= {
    'https://www.oyorooms.com/hotels-in-goa/?page=4',
    'https://www.oyorooms.com/hotels-in-goa/?page=3',
    'https://www.oyorooms.com/hotels-in-goa/?page=2',
    'https://www.oyorooms.com/hotels-in-goa/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in goa:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'goa',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
goa = pd.DataFrame(all_data)

# Display the DataFrame
goa
# Out:
#    Place                               Hotel Name  \
# 0    goa                   Hotel O Sai Deep Place
# 1    goa      Hotel O Holiday Suites Benaulim Goa
# 2    goa                Hotel O Amigo Guest House
# 3    goa                       Hotel O Relax Stay
# 4    goa              Hote O Pravin Holiday Homes
# ..   ...                                      ...
# 75   goa                      Collection O Morjim
# 76   goa                   Super Hotel O Porvorim
# 77   goa               Hotel O Benaulim Beach Goa
# 78   goa  Super Townhouse Calangute - Baga Circle
# 79   goa             SPOT ON 36887 PS Guest House
#
#                                           Destination Actual Price  \
# 0                                      North Goa, Goa        ₹7148
# 1                                           Goa , Goa        ₹5957
# 2                                   Praias Waddo, Goa        ₹6115
# 3                    1.4 km from Reis Magos Fort, Goa        ₹6309
# ...

# %%
gorakhpur= {
    'https://www.oyorooms.com/hotels-in-gorakhpur/?page=2',
    'https://www.oyorooms.com/hotels-in-gorakhpur/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gorakhpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gorakhpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gorakhpur = pd.DataFrame(all_data)

# Display the DataFrame
gorakhpur
# Out:
#         Place                                         Hotel Name  \
# 0   gorakhpur                                   Hotel O Aayaansh
# 1   gorakhpur                               HOTAL O DREAM PALACE
# 2   gorakhpur                                  Hotel O R V Palce
# 3   gorakhpur                      HOTEL O BLISS INN GUEST HOUSE
# 4   gorakhpur                            Hotel O Mayur Residency
# 5   gorakhpur                                   Hotel O Nice Inn
# 6   gorakhpur                                Hotel O Pragati Inn
# 7   gorakhpur   Super Hotel O Krishna guest house and restaurant
# 8   gorakhpur                             Hotel O Tapasya Palace
# 9   gorakhpur                                 Hotel O Kasol Inn
# 10  gorakhpur                         Hotel O Govind Guest House
# 11  gorakhpur                Super Hotel O Sada Shiv Guest House
# 12  gorakhpur                                 Hotel O The Spark
# ...

# %%
guntur= {
    'https://www.oyorooms.com/hotels-in-guntur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in guntur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'guntur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
guntur = pd.DataFrame(all_data)

# Display the DataFrame
guntur
# Out:
#      Place                               Hotel Name  \
# 0   guntur  Hotel O Amaravathi Road Annapurna Nagar
# 1   guntur                     Super Hotel O Guntur
# 2   guntur                      Hotel O V Guest In
# 3   guntur                    SPOT ON Swarna Mayuri
# 4   guntur             Super Hotel O Aditya Premier
# 5   guntur                 Hotel O Aditya Grand Inn
# 6   guntur                   Capital O Aditya Grand
# 7   guntur           Hotel O Varsha Grand Residence
# 8   guntur                  SPOT ON Sri Surya Lodge
# 9   guntur                Hotel O Vididhi Guest In
# 10  guntur           Hotel O MOON LIGHT GUEST ROOMS
# 11  guntur             Hotel O GANESH MAHALAKMI INN
# 12  guntur                Hotel O Relax Guest Rooms
# 13  guntur                    Hotel O Jaya Fortune
# 14  guntur              Hotel O Sri New Sai Chandra
# 15  guntur                  Hotel O J3 LUXURY ROOMS
# 16  guntur                        Hotel O Rajadhani
# ...

# %%
gurgaon= {
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=6',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=5',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=4',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=3',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=2',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gurgaon:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gurgaon',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gurgaon = pd.DataFrame(all_data)

# Display the DataFrame
gurgaon
# Out:
#        Place                                         Hotel Name  \
# 0    gurgaon                         Townhouse Sector 4 Gurgaon
# 1    gurgaon                                Hotel O Star hotel
# 2    gurgaon  Super Collection O Sector 45 Near Huda Metro S...
# 3    gurgaon                   Collection O Sadar Bazar Gurgaon
# 4    gurgaon                              Townhouse Delight Inn
# ..       ...                                                ...
# 115  gurgaon                           Hotel O Royal Collection
# 116  gurgaon                              Hotel O Starlight Inn
# 117  gurgaon    Hotel O Comfort Residency Near Artemis Hospital
# 118  gurgaon                          Super Townhouse CLOUD BAY
# 119  gurgaon                          Hotel O Shivaay Residency
#
#                                           Destination Actual Price  \
# 0                       Laxman Vihar Phase 2, Gurgaon        ₹3294
# ...

# %%
guwahati= {
    'https://www.oyorooms.com/hotels-in-guwahati/?page=4',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=3',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=2',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in guwahati:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'guwahati',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
guwahati = pd.DataFrame(all_data)

# Display the DataFrame
guwahati
# Out:
#        Place                                         Hotel Name  \
# 0   guwahati  Super Townhouse Zoo Road Near Guwahati Central...
# 1   guwahati                            Hotel O Home Road House
# 2   guwahati                        Super Townhouse Oak GS Road
# 3   guwahati                            Super Collection O ISBT
# 4   guwahati  Super Hotel O Noonmati Guwahati formerly Hotel...
# ..       ...                                                ...
# 75  guwahati                                  Hotel O Hill View
# 76  guwahati                        Hotel O Aashray Guest House
# 77  guwahati                                  Hotel O Sai Villa
# 78  guwahati                        Collection O Ashirbad Lodge
# 79  guwahati                                Hotel O Siddhivilla
#
#                                           Destination Actual Price  \
# 0   Near Guwahati Central, lakhimi path, Zoo road,...        ₹5269
# ...

# %%
guntur= {
    'https://www.oyorooms.com/hotels-in-guntur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in guntur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'guntur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
guntur = pd.DataFrame(all_data)

# Display the DataFrame
guntur
# Out:
#      Place                               Hotel Name  \
# 0   guntur  Hotel O Amaravathi Road Annapurna Nagar
# 1   guntur                     Super Hotel O Guntur
# 2   guntur                      Hotel O V Guest In
# 3   guntur                    SPOT ON Swarna Mayuri
# 4   guntur             Super Hotel O Aditya Premier
# 5   guntur                 Hotel O Aditya Grand Inn
# 6   guntur                   Capital O Aditya Grand
# 7   guntur           Hotel O Varsha Grand Residence
# 8   guntur                  SPOT ON Sri Surya Lodge
# 9   guntur                Hotel O Vididhi Guest In
# 10  guntur           Hotel O MOON LIGHT GUEST ROOMS
# 11  guntur             Hotel O GANESH MAHALAKMI INN
# 12  guntur                Hotel O Relax Guest Rooms
# 13  guntur                    Hotel O Jaya Fortune
# 14  guntur              Hotel O Sri New Sai Chandra
# 15  guntur                  Hotel O J3 LUXURY ROOMS
# 16  guntur                        Hotel O Rajadhani
# ...

# %%
gurgaon= {
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=6',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=5',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=4',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=3',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=2',
    'https://www.oyorooms.com/hotels-in-gurgaon/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gurgaon:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gurgaon',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gurgaon = pd.DataFrame(all_data)

# Display the DataFrame
gurgaon
# Out:
#        Place                                         Hotel Name  \
# 0    gurgaon                         Townhouse Sector 4 Gurgaon
# 1    gurgaon                                Hotel O Star hotel
# 2    gurgaon  Super Collection O Sector 45 Near Huda Metro S...
# 3    gurgaon                   Collection O Sadar Bazar Gurgaon
# 4    gurgaon                              Townhouse Delight Inn
# ..       ...                                                ...
# 115  gurgaon                           Hotel O Royal Collection
# 116  gurgaon                              Hotel O Starlight Inn
# 117  gurgaon    Hotel O Comfort Residency Near Artemis Hospital
# 118  gurgaon                          Super Townhouse CLOUD BAY
# 119  gurgaon                          Hotel O Shivaay Residency
#
#                                           Destination Actual Price  \
# 0                       Laxman Vihar Phase 2, Gurgaon        ₹3294
# ...

# %%
guwahati= {
    'https://www.oyorooms.com/hotels-in-guwahati/?page=4',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=3',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=2',
    'https://www.oyorooms.com/hotels-in-guwahati/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in guwahati:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'guwahati',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
guwahati = pd.DataFrame(all_data)

# Display the DataFrame
guwahati
# Out:
#        Place                                         Hotel Name  \
# 0   guwahati  Super Townhouse Zoo Road Near Guwahati Central...
# 1   guwahati                            Hotel O Home Road House
# 2   guwahati                        Super Townhouse Oak GS Road
# 3   guwahati                            Super Collection O ISBT
# 4   guwahati  Super Hotel O Noonmati Guwahati formerly Hotel...
# ..       ...                                                ...
# 75  guwahati                                  Hotel O Hill View
# 76  guwahati                        Hotel O Aashray Guest House
# 77  guwahati                                  Hotel O Sai Villa
# 78  guwahati                        Collection O Ashirbad Lodge
# 79  guwahati                                Hotel O Siddhivilla
#
#                                           Destination Actual Price  \
# 0   Near Guwahati Central, lakhimi path, Zoo road,...        ₹5269
# ...

# %%
gwalior= {
    'https://www.oyorooms.com/hotels-in-gwalior/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in gwalior:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'gwalior',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
gwalior = pd.DataFrame(all_data)

# Display the DataFrame
gwalior
# Out:
#       Place                                         Hotel Name  \
# 0   gwalior  Super Collection O Kampoo Tiraha Road formerly...
# 1   gwalior  Super Hotel O Mall Road Gwalior formerly Rama inn
# 2   gwalior                      Townhouse Adityapuram Gwalior
# 3   gwalior  Super Townhouse Padav Square Gwalior formerly ...
# 4   gwalior   Collection O Phalka Bazaar Gwalior formerly Bliv
# 5   gwalior  Super Townhouse City Centre Road formerly Roya...
# 6   gwalior   Super Hotel O Kalpi Road formerly Hotel Gajanand
# 7   gwalior  Hotel O Shinde Ki Chhawni Gwalior formerly Yug...
# 8   gwalior                                   Hotel O High Sky
# 9   gwalior                                 Hotel O Heaven Inn
# 10  gwalior                                    Capital O Relax
# 11  gwalior                                      Hotel O Dream
# 12  gwalior                                Hotel O Plaza Lodge
# 13  gwalior                 SPOT ON 66974 Hotel shri gurukripa
# ...

# %%
haridwar= {
    'https://www.oyorooms.com/hotels-in-haridwar/?page=2',
    'https://www.oyorooms.com/hotels-in-haridwar/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in haridwar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'haridwar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
haridwar = pd.DataFrame(all_data)

# Display the DataFrame
haridwar
# Out:
#        Place                                         Hotel Name  \
# 0   haridwar  Super Hotel O Haridwar Near Shanti Kunj Bhupat...
# 1   haridwar        Super Hotel O Jwalapur Near Railway Station
# 2   haridwar            Super Collection O Shanti Kunj Haridwar
# 3   haridwar            Super Hotel O Indira Enclave Bhupatwala
# 4   haridwar                               Hotel O Mehfil Hotel
# 5   haridwar                         Hotel O Pdi Health Resorts
# 6   haridwar                   Hotel O Ganga Valley Guest House
# 7   haridwar    Hotel O Rudreshwar By Shri Krishna Taxi Service
# 8   haridwar                                Hotel O Dwarkadhish
# 9   haridwar                       Hotel O Hill Way Guest House
# 10  haridwar                            Collection O The Orient
# 11  haridwar                                  Hotel O Mangal In
# 12  haridwar                       Hotel O Shiv Ganga Home Stay
# 13  haridwar                                    Hotel O Chauhan
# ...

# %%
hisar= {
    'https://www.oyorooms.com/hotels-in-hisar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in hisar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'hisar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
hisar = pd.DataFrame(all_data)

# Display the DataFrame
hisar
# Out:
#     Place                               Hotel Name  \
# 0   hisar                Super Townhouse Oak Hisar
# 1   hisar                   Collection O Raj Mahal
# 2   hisar                          Hotel O Midland
# 3   hisar                        Hotel O Blue Moon
# 4   hisar                           Hotel O Plazza
# 5   hisar                              Hotel O HSR
# 6   hisar                      Super Hotel O Green
# 7   hisar                          Hotel O SkyCity
# 8   hisar                        Hotel O Paris Inn
# 9   hisar                      Hotel O Airport Inn
# 10  hisar                         Hotel O CO Hotel
# 11  hisar                           Hotel O Magnum
# 12  hisar                    Hotel O Bishnoi Hotel
# 13  hisar                     Hotel O Diamond Star
# 14  hisar                     Hotel O SANGAM HOTEL
# 15  hisar                     Hotel O Satyam Tower
# 16  hisar  Collection O Mukur Hotel And Restaurant
# ...

# %%
hyderabad= {
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=15',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=14',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=13',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=12',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=11',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=10',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=9',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=8',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=7',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=6',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=5',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=4',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=3',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=2',
    'https://www.oyorooms.com/hotels-in-hyderabad/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in hyderabad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'hyderabad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
hyderabad = pd.DataFrame(all_data)

# Display the DataFrame
hyderabad
# Out:
#          Place                                    Hotel Name  \
# 0    hyderabad                  Super Hotel O Yadagiri Gutta
# 1    hyderabad  Hotel O Sri Residency Near Hyderabad Central
# 2    hyderabad                                 Hotel O 9 Inn
# 3    hyderabad                          Hotel O Sree Krishna
# 4    hyderabad               Super Hotel O Alpine Glow Crest
# ..         ...                                           ...
# 295  hyderabad                     Hotel O Mayur's residency
# 296  hyderabad            Hotel O 14726 Hotel Vaishnavi Park
# 297  hyderabad                       Hotel O Priya Residency
# 298  hyderabad                    Super Townhouse Lakdikapul
# 299  hyderabad                   Super Hotel O Vaishnavi Inn
#
#                                            Destination Actual Price  \
# 0    Srivari City Residency, plot no.17 wadaigudem,...        ₹3534
# 1                                  Ameerpet, Hyderabad        ₹3842
# ...

# %%
indore= {
    'https://www.oyorooms.com/hotels-in-indore/?page=4',
    'https://www.oyorooms.com/hotels-in-indore/?page=3',
    'https://www.oyorooms.com/hotels-in-indore/?page=2',
    'https://www.oyorooms.com/hotels-in-indore/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in indore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'indore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
indore = pd.DataFrame(all_data)

# Display the DataFrame
indore
# Out:
#      Place                    Hotel Name  \
# 0   indore             Hotel O Rudra Inn
# 1   indore         Townhouse Gandhi Hall
# 2   indore  Townhouse Pipliyahana Square
# 3   indore        Hotel O Paradise Green
# 4   indore            Hotel O Chirag Inn
# ..     ...                           ...
# 75  indore    Collection O Riddhi Siddhi
# 76  indore          Hotel O Chandragupta
# 77  indore              Hotel O Madhuban
# 78  indore         HOTEL O GRAND GIRIRAJ
# 79  indore             Hotel O Aashirwad
#
#                                           Destination Actual Price  \
# 0                                near it park, Indore        ₹2778
# 1                   Near GANDHI HALL, Mg Road, Indore        ₹5188
# 2         Near Highway, Brajeshwari Extension, Indore        ₹3848
# 3   60-Feet Road indore (near airport ) 277-278 Am...        ₹2697
# 4   Sudama Nagar Opp. Annapurna Mandir Near Annapu...        ₹2578
# ...

# %%
jabalpur= {
    'https://www.oyorooms.com/hotels-in-jabalpur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jabalpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jabalpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jabalpur = pd.DataFrame(all_data)

# Display the DataFrame
jabalpur
# Out:
#        Place                        Hotel Name  \
# 0   jabalpur  Hotel O atithi in Garha Jabalpur
# 1   jabalpur         Hotel O Dhan Mahal Resort
# 2   jabalpur               Hotel O Dwarika Inn
# 3   jabalpur                   Hotel O CityMax
# 4   jabalpur          Hotel O Sanskardhani Inn
# 5   jabalpur              Hotel O Orchid Homes
# 6   jabalpur                  Capital O Kartik
# 7   jabalpur     Hotel O Russel Chowk Jabalpur
# 8   jabalpur  SPOT ON Krishna Market And Lodge
# 9   jabalpur                  SPOT ON Standard
# 10  jabalpur                    Hotel O Mystic
# 11  jabalpur               Hotel O Maa Narmada
# 12  jabalpur                 Hotel O ANUSHTHAN
# 13  jabalpur                 HOTEL O ORVIN INN
# 14  jabalpur             Hotel O Godavari Lawn
# 15  jabalpur              Hotel O Paradise Inn
# 16  jabalpur               HOTEL O KINGS PRIDE
#
#                                           Destination Actual Price  \
# ...

# %%
jaipur= {
    'https://www.oyorooms.com/hotels-in-jaipur/?page=9',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=8',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=7',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=6',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=5',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=4',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=3',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=2',
    'https://www.oyorooms.com/hotels-in-jaipur/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jaipur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jaipur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jaipur = pd.DataFrame(all_data)

# Display the DataFrame
jaipur
# Out:
#       Place                                         Hotel Name  \
# 0    jaipur  Super Hotel O Kaveri Path formerly Shree Sai R...
# 1    jaipur                                 HOTEL O BUNGLOW 18
# 2    jaipur   Super Townhouse JLN Marg formerly Ritz Residency
# 3    jaipur  Super Townhouse Collectorate Circle formerly L...
# 4    jaipur                HOTEL O JAI PALACE AND GUEST HOUSE
# ..      ...                                                ...
# 175  jaipur  Townhouse Oak Amrapali Circle Formerly Hotel Aqua
# 176  jaipur                                      Vip Inn Hotel
# 177  jaipur                                    Hotel O Daily 2
# 178  jaipur                          Hotel O Hill View Resorts
# 179  jaipur                                 SPOT ON Hotel Rj14
#
#                                         Destination Actual Price  \
# 0                                Mansarovar, Jaipur        ₹4499
# 1             Sodala Jaipur Rajsthan 302020, Jaipur        ₹2960
# ...

# %%
jalandhar= {
    'https://www.oyorooms.com/hotels-in-jalandhar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jalandhar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jalandhar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jalandhar = pd.DataFrame(all_data)

# Display the DataFrame
jalandhar
# Out:
#        Place                           Hotel Name  \
# 0  jalandhar  Super Hotel O Shiv Sai Guest House
# 1  jalandhar                          Hotel O Max
# 2  jalandhar                       81157G Amy Inn
# 3  jalandhar                    Hotel O Inder Inn
# 4  jalandhar                  Hotel O PLAZA GRAND
# 5  jalandhar  Super Collection O Ovel Hotel Grand
# 6  jalandhar                     Hotel O Rajmahal
# 7  jalandhar                 Hotel O Himmat House
# 8  jalandhar                 Hotel O Blessing Inn
#
#                                          Destination Actual Price  \
# 0                                 Nakodar, Jalandhar        ₹3345
# 1  New Grain Market Near Hmv College Workshop Cho...        ₹3588
# 2  lovely professional University law gate near m...        ₹2853
# 3  Gully no.13/Main Road/Avtar Nagar/Near BOI, Ja...        ₹3817
# 4       Near Dilkusha Market, Civil Lines, Jalandhar        ₹3784
# ...

# %%
jammu= {
    'https://www.oyorooms.com/hotels-in-jammu/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jammu:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jammu',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jammu = pd.DataFrame(all_data)

# Display the DataFrame
jammu
# Out:
#    Place                                         Hotel Name  \
# 0  jammu                                   Hotel O New Fiza
# 1  jammu            Hotel O Homewood Suites And Guest House
# 2  jammu                         Hotel O 62748 Hotel Zeenat
# 3  jammu                                       Hotel O Ajay
# 4  jammu                                   Hotel O Starwood
# 5  jammu                                     Hotel O Indira
# 6  jammu  Hotel O Jammu Near Ragunath Bazaar formerly Go...
# 7  jammu                        Super Hotel O Maa Residency
#
#                                          Destination Actual Price  \
# 0                                       Jammu, Jammu        ₹4319
# 1                                       Jammu, Jammu        ₹5381
# 2            2 kms from Bahu Fort  near Gujjar Nagar        ₹6567
# 3                    400 meter from Raghunath Temple        ₹4778
# 4                                       Jammu, Jammu        ₹6707
# ...

# %%
jamshedpur= {
    'https://www.oyorooms.com/hotels-in-jamshedpur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jamshedpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jamshedpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jamshedpur = pd.DataFrame(all_data)

# Display the DataFrame
jamshedpur
# Out:
#          Place                                         Hotel Name  \
# 0   jamshedpur                             Collection O Greenpark
# 1   jamshedpur  Super Townhouse Oak Pardih Chowk Mango Formerl...
# 2   jamshedpur                                    Hotel O Suvidha
# 3   jamshedpur                          Hotel O Mini Punjab Hills
# 4   jamshedpur                         Super Hotel O DEGREE HOTEL
# 5   jamshedpur                                Hotel O Prakash Inn
# 6   jamshedpur                         Super Hotel O Om Residency
# 7   jamshedpur                                       Hotel O Vira
# 8   jamshedpur                           Hotel O Sourya Residency
# 9   jamshedpur                               Hotel O Premium Hari
# 10  jamshedpur                            Super Hotel O Subheksha
# 11  jamshedpur                            Collection O Aditya Inn
# 12  jamshedpur                                 Hotel O The Orchid
# ...

# %%
jodhpur= {
    'https://www.oyorooms.com/hotels-in-jodhpur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in jodhpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'jodhpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
jodhpur = pd.DataFrame(all_data)

# Display the DataFrame
jodhpur
# Out:
#       Place                                         Hotel Name  \
# 0   jodhpur  Super Collection O Rai Ka Bagh Near Railway St...
# 1   jodhpur                             Hotel O Stayvillas BNB
# 2   jodhpur                        Hotel O Anand Hotel Jodhpur
# 3   jodhpur                                   Hotel O High Sky
# 4   jodhpur                             Hotel O Devmahal Hotel
# 5   jodhpur                          Hotel O BLUE BARREL HOTEL
# 6   jodhpur                                   Hotel O Azad Inn
# 7   jodhpur                       Super Hotel O Jagmohan Hotel
# 8   jodhpur                               Hotel O Paradise Inn
# 9   jodhpur                      Super Hotel O BlackBull Hotel
# 10  jodhpur                  Super Collection O S B Excellency
# 11  jodhpur                               SPOT ON Sapphire Inn
# 12  jodhpur                               Capital O Maurya Inn
# 13  jodhpur                                        Hotel O H2O
# ...

# %%
kakinada= {
    'https://www.oyorooms.com/hotels-in-kakinada/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kakinada:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kakinada',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kakinada = pd.DataFrame(all_data)

# Display the DataFrame
kakinada
# Out:
#        Place                                     Hotel Name  \
# 0   kakinada          Super Collection O Kakinada near JNTU
# 1   kakinada                 Capital O De Alphabet Kakinada
# 2   kakinada                        Hotel O Sea Coastal Inn
# 3   kakinada  Hotel O Coastal Inn Luxury Service Apartments
# 4   kakinada                        Palette - Hilife Towers
# 5   kakinada                            Hotel O Sea Coastal
# 6   kakinada                      Super Hotel O Coastal Inn
# 7   kakinada                              SEA COASTAL INN-3
# 8   kakinada                     SPOT ON Sri Devi Residency
# 9   kakinada    Super Hotel O Ashok Nagar Near JNTU College
# 10  kakinada   Super Hotel O Ramaraopet Near Kakinada Beach
#
#                                           Destination Actual Price  \
# 0     Near Kshatriya Foods, Nagamalli Thota, Kakinada        ₹5877
# 1   Near Sai Bhaba temple, Near Water Tank, Venkat...        ₹9929
# ...

# %%
kalimpong= {
    'https://www.oyorooms.com/hotels-in-kalimpong/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kalimpong:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kalimpong',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kalimpong = pd.DataFrame(all_data)

# Display the DataFrame
kalimpong
# Out:
#        Place                            Hotel Name  \
# 0  kalimpong                     Hotel O Greenwood
# 1  kalimpong  HOTEL O MOUNTAIN ECOHOMES & HOMESTAY
# 2  kalimpong            Hotel O Pradhann Home Stay
# 3  kalimpong            Hotel O Jwajalapa Homestay
#
#                                 Destination Actual Price Offer Percentage  \
# 0          Near Lava Bazar, Lava, Kalimpong        ₹4048          71% off
# 1                    Sunwar Gaon, Kalimpong        ₹4277          71% off
# 2  Near Rangpo Kashone Khasmahal, Kalimpong       ₹10039          72% off
# 3               Near Relly Bazar, Kalimpong           NA               NA
#
#    Price      Ratings     Review
# 0   ₹928  (3 Ratings)  Very Good
# 1   ₹982  (1 Ratings)       Fair
# 2  ₹2350  (1 Ratings)   Fabulous
# 3     NA           NA         NA

# %%
kannur= {
    'https://www.oyorooms.com/hotels-in-kannur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kannur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kannur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kannur = pd.DataFrame(all_data)

# Display the DataFrame
kannur
# Out:
#     Place                  Hotel Name  \
# 0  kannur  Hotel O Al Ameen Residency
# 1  kannur      Hotel O AURA RESIDENCY
#
#                                          Destination Actual Price  \
# 0  Near Kannur International Airport, Mattanur-Ku...        ₹6971
# 1                                   Payyanur, Kannur        ₹8092
#
#   Offer Percentage  Price       Ratings     Review
# 0          71% off  ₹1661  (73 Ratings)  Very Good
# 1          72% off  ₹1888  (20 Ratings)  Very Good

# %%
kanpur= {
    'https://www.oyorooms.com/hotels-in-kanpur/?page=4',
    'https://www.oyorooms.com/hotels-in-kanpur/?page=3',
    'https://www.oyorooms.com/hotels-in-kanpur/?page=2',
    'https://www.oyorooms.com/hotels-in-kanpur/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kanpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kanpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kanpur = pd.DataFrame(all_data)

# Display the DataFrame
kanpur
# Out:
#      Place                                      Hotel Name  \
# 0   kanpur     Collection O Townhouse Lemonade Shyam Nagar
# 1   kanpur                             SPOT ON H.R. Hottle
# 2   kanpur                       Hotel O STAR DIVINE HOTEL
# 3   kanpur                             Hotel O VIVEK GRAND
# 4   kanpur                               Hotel O The Skies
# ..     ...                                             ...
# 75  kanpur                           Hotel O Star The View
# 76  kanpur      Hotel O sunrise guest house and restaurant
# 77  kanpur  Collection O Siddharth Near A to Z Electronics
# 78  kanpur                                  Hotel O Samrat
# 79  kanpur                            Hotel O Samrat Hotel
#
#                                           Destination Actual Price  \
# 0   Andha Modh V Square Plaza Pac Road Shyam Nagar...        ₹6712
# 1                                Kanpur dehat, Kanpur        ₹2912
# ...

# %%
kanyakumari= {
    'https://www.oyorooms.com/hotels-in-kanyakumari/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kanyakumari:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kanyakumari',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kanyakumari = pd.DataFrame(all_data)

# Display the DataFrame
kanyakumari
# Out:
#          Place                                         Hotel Name  \
# 0  kanyakumari  Hotel O Kanyakumari Near Chinna Muttam Beach f...
# 1  kanyakumari  Super Hotel O Kanyakumari Near Sunrise View fo...
# 2  kanyakumari                              Super Hotel O Aljemin
# 3  kanyakumari                       Hotel O Sri Sakthi Residency
#
#                                          Destination Actual Price  \
# 0  Near Kanyakumari Arch, Vivekanandapuram, Kanya...        ₹3640
# 1                                        Kanyakumari        ₹3574
# 2                  Near Railway Station, Kanyakumari        ₹5460
# 3                           Sakthinagar, Kanyakumari        ₹5824
#
#   Offer Percentage  Price        Ratings     Review
# 0          76% off   ₹686   (31 Ratings)  Very Good
# 1          73% off   ₹804  (334 Ratings)  Excellent
# 2          77% off  ₹1017  (424 Ratings)  Excellent
# 3          72% off  ₹1295   (24 Ratings)       Fair

# %%
karnal= {
    'https://www.oyorooms.com/hotels-in-karnal/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in karnal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'karnal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
karnal = pd.DataFrame(all_data)

# Display the DataFrame
karnal
# Out:
#     Place           Hotel Name  \
# 0  karnal  Super Hotel O Pearl
# 1  karnal       Hotel O Shagun
#
#                                         Destination Actual Price  \
# 0  Opposite Vishal Mega Mart, Kunjpura Road, Karnal        ₹2754
# 1             Near Sri Ram Temple, Sector 9, Karnal        ₹3178
#
#   Offer Percentage Price        Ratings    Review
# 0          72% off  ₹624  (317 Ratings)  Fabulous
# 1          68% off  ₹806   (33 Ratings)      Good

# %%
katra= {
    'https://www.oyorooms.com/hotels-in-katra/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in katra:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'katra',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
katra = pd.DataFrame(all_data)

# Display the DataFrame
katra
# Out:
#    Place                                         Hotel Name  \
# 0  katra  Super Collection O Jammu Road formerly Katra R...
# 1  katra                              Hotel O Gauri Shankar
# 2  katra                  Collection O The Shree Dhar Niwas
# 3  katra                          Collection O Gordon House
#
#                           Destination Actual Price Offer Percentage  Price  \
# 0                   Jammu Road, Katra        ₹6464          68% off  ₹1707
# 1  Back side of Hotel jagdamba, Katra        ₹8828          67% off  ₹2360
# 2                        Katra, Katra        ₹8828          72% off  ₹2050
# 3                        Katra, Katra        ₹8828          68% off  ₹2286
#
#         Ratings    Review
# 0  (46 Ratings)  Fabulous
# 1   (7 Ratings)  Fabulous
# 2   (3 Ratings)      Fair
# 3   (7 Ratings)      Fair

# %%
khammam= {
    'https://www.oyorooms.com/hotels-in-khammam/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in khammam:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'khammam',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
khammam = pd.DataFrame(all_data)

# Display the DataFrame
khammam
# Out:
#      Place                                 Hotel Name  \
# 0  khammam    Super Townhouse Gollagudem Road Khammam
# 1  khammam  Super Townhouse Khammam formerly Bluemoon
# 2  khammam                    Hotel O Arjun Residency
# 3  khammam                            Hotel O Sridhar
# 4  khammam                         Hotel O Mango Tree
# 5  khammam                           Hotel O PR GRAND
#
#                                        Destination Actual Price  \
# 0                       Vivekananda Nagar, Khammam        ₹4631
# 1     Near Sri krishna Emergency Hospital, Khammam        ₹4201
# 2                            Netaji Nagar, Khammam        ₹3499
# 3  Opp old bustand,mayuricenter,wyra road, khammam        ₹3841
# 4                             khammamnull, Khammam        ₹4579
# 5                     Near Sri Sri circle, Khammam        ₹5231
#
#   Offer Percentage  Price        Ratings     Review
# 0          71% off  ₹1049  (223 Ratings)  Excellent
# ...

# %%
kochi= {
    'https://www.oyorooms.com/hotels-in-kochi/?page=3',
    'https://www.oyorooms.com/hotels-in-kochi/?page=2',
    'https://www.oyorooms.com/hotels-in-kochi/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kochi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kochi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kochi = pd.DataFrame(all_data)

# Display the DataFrame
kochi
# Out:
#     Place                                         Hotel Name  \
# 0   kochi                          Townhouse Ernakulam North
# 1   kochi                      Super Townhouse Malabar Illam
# 2   kochi                        Super Hotel O Versatile Inn
# 3   kochi               Hotel O Elegant KINGS PARK RESIDENCY
# 4   kochi                              Hotel O New Famy Home
# 5   kochi             Super Hotel O Crystal Executive Suites
# 6   kochi                           Super Hotel O Diamond In
# 7   kochi                     Hotel O HOTEL BOLGATTY REGENT
# 8   kochi                          Hotel O High 5 Apartments
# 9   kochi                       Hotel O Thykoodam Apartments
# 10  kochi          Super Townhouse  Mookkannoor Tourist Home
# 11  kochi                        Super Hotel O EVA RESIDENCY
# 12  kochi                                 Hotel O LIME Light
# 13  kochi                Super Townhouse Edasserys Sea Pearl
# ...

# %%
kodaikanal= {
    'https://www.oyorooms.com/hotels-in-kodaikanal/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kodaikanal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kodaikanal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kodaikanal = pd.DataFrame(all_data)

# Display the DataFrame
kodaikanal
# Out:
#         Place                                      Hotel Name  \
# 0  kodaikanal                  Super Collection O Perumpallam
# 1  kodaikanal  Hotel O Kodaikanal Vilpatti formerly Kodai Hut
# 2  kodaikanal                    Hotel O Dev Holiday Homestay
# 3  kodaikanal                     Hotel O Ding Dong Residency
# 4  kodaikanal                               Hotel O SLR Homes
# 5  kodaikanal                  Collection O AMARAN SHOLA NEST
# 6  kodaikanal                             Hotel O Angel Nivas
#
#                               Destination Actual Price Offer Percentage  \
# 0                 Perumballam, Kodaikanal        ₹3813          78% off
# 1                    Vilpatti, Kodaikanal        ₹3203          71% off
# 2             Sreenivasapuram, Kodaikanal        ₹6264          72% off
# 3                 Kodaikanal , Kodaikanal        ₹5888          71% off
# 4                  Kodaikanal, Kodaikanal        ₹6066          73% off
# ...

# %%
kolkata= {
    'https://www.oyorooms.com/hotels-in-kolkata/?page=12',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=11',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=10',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=9',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=8',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=7',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=6',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=5',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=4',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=3',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=2',
    'https://www.oyorooms.com/hotels-in-kolkata/?page=1'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kolkata:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kolkata',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kolkata = pd.DataFrame(all_data)

# Display the DataFrame
kolkata
# Out:
#        Place                                       Hotel Name  \
# 0    kolkata                                 Hotel O City Inn
# 1    kolkata         Collection O Raj Darbar Near City Centre
# 2    kolkata                Super Hotel O Royal Crown Banquet
# 3    kolkata                                  Hotel O Mrs Inn
# 4    kolkata                       Hotel O Falcon Guest House
# ..       ...                                              ...
# 235  kolkata                    Super Hotel O 82938 Grand Inn
# 236  kolkata              Hotel O New Town Near Downtown Mall
# 237  kolkata                                Hotel O 4 Friends
# 238  kolkata              Super Hotel O Kaikhali Near Airport
# 239  kolkata  Townhouse Habitat New Town Rooms & Party Spaces
#
#                                            Destination Actual Price  \
# 0                             Avisar Spencer Kalikapur        ₹2790
# 1                                     Newtown, Kolkata        ₹4964
# ...

# %%
kollam= {
    'https://www.oyorooms.com/hotels-in-kollam/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kollam:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kollam',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kollam = pd.DataFrame(all_data)

# Display the DataFrame
kollam
# Out:
#      Place                        Hotel Name  \
# 0   kollam      Hotel O Revathy Tourist Home
# 1   kollam              Hotel O SS Residency
# 2   kollam          SPOT ON J P Tourist Home
# 3   kollam             Townhouse Dona Castle
# 4   kollam         Collection O Rohini Hills
# 5   kollam          Hotel O Quilon Residency
# 6   kollam              Hotel O Catha Castle
# 7   kollam  Hotel O Sree Bhadra Tourist Home
# 8   kollam     Collection O Narendra Regency
# 9   kollam                 Hotel O B&B Rooms
# 10  kollam         SPOT ON Sana Tourist Home
#
#                                           Destination Actual Price  \
# 0                                      kollam, Kollam        ₹4681
# 1                                     Punalur, Kollam        ₹4638
# 2                                 Chinnakkada, Kollam        ₹3434
# 3     Near Lakshminada Main Road, Vidya Nagar, Kollam        ₹8988
# 4                                     Punalur, Kollam        ₹6712
# ...

# %%
kota= {
    'https://www.oyorooms.com/hotels-in-kota/?page=2',
    'https://www.oyorooms.com/hotels-in-kota/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kota:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kota',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kota = pd.DataFrame(all_data)

# Display the DataFrame
kota
# Out:
#    Place                                         Hotel Name  \
# 0   kota                          Hotel O Kanchan Residency
# 1   kota                             SPOT ON Lakshay Resort
# 2   kota                                Hotel O Pink Orchid
# 3   kota                          Hotel O Girdharwal Resort
# 4   kota                                  Hotel O B Shiv Ji
# 5   kota                                    Hotel O Agarwal
# 6   kota                                Hotel O Shiv Shakti
# 7   kota                           Hotel O Saraswati Resort
# 8   kota                             Hotel O Reyansh Galaxy
# 9   kota                     Hotel O Eleven Hotel & Banquet
# 10  kota                    Hotel O Om Hotel And Restaurant
# 11  kota         Townhouse Indravihar formerly Shaily Royal
# 12  kota  Super Hotel O Kota Near Railway Station former...
# 13  kota                             SPOT ON hotel Himalaya
# 14  kota  Super Hotel O Tirupati Nagar Kota formerly Jay...
# ...

# %%
kovalam= {
    'https://www.oyorooms.com/hotels-in-kovalam/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kovalam:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kovalam',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kovalam = pd.DataFrame(all_data)

# Display the DataFrame
kovalam
# Out:
#      Place                                  Hotel Name  \
# 0  kovalam  Super Collection O Companion Leisure Homes
# 1  kovalam                  Hotel O Sandhra Apartments
# 2  kovalam           Hotel O KAYALKARA VILLA BY LEFORT
# 3  kovalam            Hotel O PULARI BACKWATER & ROOMS
# 4  kovalam             SPOT ON Ocean Ac & Non Ac Hotel
# 5  kovalam            Hotel O Ocean Queen Palace Hotel
# 6  kovalam                      Hotel O Trivi Homestay
# 7  kovalam                             Hotel O Seaweed
# 8  kovalam                        Hotel O Dream Palace
# 9  kovalam                  Hotel O Poptavern Heritage
#
#                           Destination Actual Price Offer Percentage  Price  \
# 0    Near KS Road, Vizhinjam, Kovalam        ₹5761          68% off  ₹1476
# 1  Near Kannadipally, Poovar, Kovalam        ₹4028          68% off  ₹1017
# 2                  vellayani, Kovalam        ₹3825          71% off   ₹902
# ...

# %%
kurukshetra= {
    'https://www.oyorooms.com/hotels-in-kurukshetra/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in kurukshetra:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'kurukshetra',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
kurukshetra = pd.DataFrame(all_data)

# Display the DataFrame
kurukshetra
# Out:
#          Place                                         Hotel Name  \
# 0  kurukshetra  Super Townhouse Brahma Sarovar formerly Krishn...
# 1  kurukshetra                                    Hotel O Patiala
# 2  kurukshetra                Hotel O Nagpal Hotel And Restaurant
#
#                                        Destination Actual Price  \
# 0                            Thanesar, Kurukshetra        ₹4447
# 1                   Near Brahma Chowk, Kurukshetra        ₹2465
# 2  Landmark- Near Ramkaran MLA office, Kurukshetra        ₹2945
#
#   Offer Percentage  Price       Ratings     Review
# 0          67% off  ₹1211  (34 Ratings)  Very Good
# 1          73% off   ₹517  (34 Ratings)       Good
# 2          71% off   ₹661  (21 Ratings)  Very Good

# %%
latur= {
    'https://www.oyorooms.com/hotels-in-latur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in latur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'latur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
latur = pd.DataFrame(all_data)

# Display the DataFrame
latur
# Out:
#    Place                    Hotel Name                           Destination  \
# 0  latur  Hotel O Pankaj Hotel & Lodge                         Katpur, Latur
# 1  latur         Hotel O Alankar Lodge    gat no 33kalam highway road, Latur
# 2  latur          Hotel O Jadhav Lodge                      Ring Road, Latur
# 3  latur      Hotel O Pravin Executive  Near Harangul Railway Station, Latur
# 4  latur     Hotel O New Diwanji Lodge                          Latur, Latur
#
#   Actual Price Offer Percentage Price        Ratings     Review
# 0        ₹2938          71% off  ₹664    (5 Ratings)  Excellent
# 1        ₹3482          72% off  ₹793    (9 Ratings)       Good
# 2        ₹3494          72% off  ₹795  (106 Ratings)       Fair
# 3        ₹3307          72% off  ₹743    (8 Ratings)       Fair
# 4           NA               NA    NA             NA         NA

# %%
lucknow= {
    'https://www.oyorooms.com/hotels-in-lucknow/?page=11',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=12',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=10',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=9',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=8',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=7',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=6',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=5',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=4',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=3',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=2',
    'https://www.oyorooms.com/hotels-in-lucknow/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in lucknow:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'lucknow',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
lucknow = pd.DataFrame(all_data)

# Display the DataFrame
lucknow
# Out:
#        Place                                  Hotel Name  \
# 0    lucknow                  Hotel O Royal inn homestay
# 1    lucknow                             Hotel O Rodstar
# 2    lucknow                   OYO 76256 Trimurti Palace
# 3    lucknow                        Hotel O Geeta Palace
# 4    lucknow                             Hotel O Dev Inn
# ..       ...                                         ...
# 235  lucknow  Super Collection O Alambagh Near Bus Stand
# 236  lucknow                       Hotel O Easy Stay Inn
# 237  lucknow              HOTEL O ANAND LOK GUEST HOUSE
# 238  lucknow                       SPOT ON SHIKHA PALACE
# 239  lucknow                                 Hotel O V R
#
#                                            Destination Actual Price  \
# 0    Gangaganj Hanumanpuri amausi station road saro...        ₹1838
# 1                                 Near Jaipuria School        ₹2999
# 2           House no 4/163 Vivek khand 4 Gomti nagar          ₹3982
# ...

# %%
ludhiana= {
    'https://www.oyorooms.com/hotels-in-ludhiana/?page=3',
    'https://www.oyorooms.com/hotels-in-ludhiana/?page=2',
    'https://www.oyorooms.com/hotels-in-ludhiana/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ludhiana:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ludhiana',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ludhiana = pd.DataFrame(all_data)

# Display the DataFrame
ludhiana
# Out:
#        Place                                         Hotel Name  \
# 0   ludhiana                          Hotel O Royal Guest House
# 1   ludhiana                                      Townhouse Sky
# 2   ludhiana                                 Hotel O Sky Orchid
# 3   ludhiana                    Hotel O 71214 Hotel Welcome Inn
# 4   ludhiana                     Collection O KOP INTERNATIONAL
# 5   ludhiana                      Super Hotel O Sky White House
# 6   ludhiana                             Super Hotel O Sky Land
# 7   ludhiana                                  Hotel O City Stay
# 8   ludhiana                        Hotel O HI - Five Residency
# 9   ludhiana                                Hotel O Grace Villa
# 10  ludhiana                                   HOTEL O ROYAL A
# 11  ludhiana                                   Hotel O Sun View
# 12  ludhiana                                        Hotel O WIN
# 13  ludhiana                                 Hotel O Silver Sky
# ...

# %%
madurai= {
    'https://www.oyorooms.com/hotels-in-madurai/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in madurai:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'madurai',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
madurai = pd.DataFrame(all_data)

# Display the DataFrame
madurai
# Out:
#      Place                            Hotel Name  \
# 0  madurai                   Hotel O Aarapalayam
# 1  madurai                       Hotel O I stayz
# 2  madurai                  Hotel O Medhaa Homes
# 3  madurai                      Hotel O MK Lodge
# 4  madurai              Hotel O Ohm Muruga Tower
# 5  madurai                      Hotel O Rj Tower
# 6  madurai                   Hotel O Anandha Inn
# 7  madurai                   Collection O MS INN
# 8  madurai                   Collection O Amaran
# 9  madurai  Super Hotel O Madurai Near Bus Stand
#
#                                          Destination Actual Price  \
# 0                               Aarapalayam, Madurai        ₹7061
# 1                              Karupayurani, Madurai        ₹8737
# 2  Hotel Poppys & Hotel Amaran Backside (Near) Ut...        ₹5785
# 3                         Thiruparankundram, Madurai        ₹6691
# 4                               Usilampatti, Madurai        ₹8258
# ...

# %%
mahabaleshwar= {
    'https://www.oyorooms.com/hotels-in-mahabaleshwar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mahabaleshwar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mahabaleshwar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mahabaleshwar = pd.DataFrame(all_data)

# Display the DataFrame
mahabaleshwar
# Out:
#            Place                                       Hotel Name  \
# 0  mahabaleshwar  Townhouse Mahabaleshwar formerly Shiva's Valley
# 1  mahabaleshwar                Collection O Mahabaleshwar Uptown
# 2  mahabaleshwar                        Hotel O Aishwarya Valley
# 3  mahabaleshwar                              Hotel O Silver Leaf
# 4  mahabaleshwar                      Collection O Rama Executive
#
#                                          Destination Actual Price  \
# 0                            Metgutad, Mahabaleshwar        ₹4622
# 1                             Nakinda, Mahabaleshwar        ₹3202
# 2                   near Mapro Garden, Mahabaleshwar        ₹4854
# 3  Plot no. 296, Dandeghar, Behind Kedareshwar Te...        ₹6691
# 4   near Mahabaleshwar Police Station, Mahabaleshwar       ₹13527
#
#   Offer Percentage  Price       Ratings     Review
# 0          77% off   ₹883  (10 Ratings)  Very Good
# 1          76% off   ₹636  (94 Ratings)  Very Good
# ...

# %%
mahabalipuram= {
    'https://www.oyorooms.com/hotels-in-mahabalipuram/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mahabalipuram:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mahabalipuram',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mahabalipuram = pd.DataFrame(all_data)

# Display the DataFrame
mahabalipuram
# Out:
#            Place                        Hotel Name  \
# 0  mahabalipuram  Super Collection O Mahabalipuram
# 1  mahabalipuram      Palette - The Galaxy Resorts
#
#                             Destination Actual Price Offer Percentage  Price  \
# 0    Police Station Road, Mahabalipuram        ₹4079          77% off   ₹764
# 1  Chengalpattu District, Mahabalipuram       ₹14969          67% off  ₹4139
#
#         Ratings     Review
# 0  (53 Ratings)  Very Good
# 1   (6 Ratings)  Excellent

# %%
manali= {
    'https://www.oyorooms.com/hotels-in-manali/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in manali:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'manali',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
manali = pd.DataFrame(all_data)

# Display the DataFrame
manali
# Out:
#     Place                                         Hotel Name  \
# 0  manali                           Hotel O Mall Road Manali
# 1  manali  Hotel O Simsa Mountain View Manali formerly An...
# 2  manali                                 Hotel O Midway Inn
# 3  manali                             Hotel O New Sun N Snow
# 4  manali                       Collection O Whistling Winds
# 5  manali                                     Hotel O Tridev
# 6  manali                          Hotel O Hema Holiday Home
# 7  manali                        Capital O Himalayan Travels
# 8  manali                                  Hotel O Sukhsagar
# 9  manali                           Hotel O ANTRIKSH COTTAGE
#
#                                Destination Actual Price Offer Percentage  \
# 0                       Model Town, Manali        ₹4015          73% off
# 1                     Chyal Tehsil, Manali        ₹4104          71% off
# ...

# %%
mandarmoni= {
    'http://oyorooms.com/hotels-in-mandarmoni/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mandarmoni:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mandarmoni',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mandarmoni = pd.DataFrame(all_data)

# Display the DataFrame
mandarmoni
# Out:
#         Place                     Hotel Name  \
# 0  mandarmoni         Hotel O Astha Homestay
# 1  mandarmoni  Hotel O Sea Face Beach Resort
# 2  mandarmoni             Hotel O S Paradise
# 3  mandarmoni                 Hotel O Gloria
#
#                                          Destination Actual Price  \
# 0                        Purba Medinipur, Mandarmoni        ₹7042
# 1  Manas kanya Manas kanya Mandarmani Beach Road,...        ₹7544
# 2  P. S -  mandarmoni coastal police statio, Mand...        ₹8791
# 3                        Purba Medinipur, Mandarmoni           NA
#
#   Offer Percentage  Price      Ratings    Review
# 0          72% off  ₹1639  (1 Ratings)  Fabulous
# 1          72% off  ₹1757  (2 Ratings)      Fair
# 2          71% off  ₹2054  (1 Ratings)  Fabulous
# 3               NA     NA  (5 Ratings)  Fabulous

# %%
manesar= {
    'https://www.oyorooms.com/hotels-in-manesar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in manesar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'manesar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
manesar = pd.DataFrame(all_data)

# Display the DataFrame
manesar
# Out:
#       Place                       Hotel Name  \
# 0   manesar         Collection O Naveen Stay
# 1   manesar       Townhouse Sector 1 Manesar
# 2   manesar          Hotel O Omi Guest House
# 3   manesar      Hotel O Dhaba 51 Mile Stone
# 4   manesar      Collection O The Royal Fern
# 5   manesar  Hotel O Four Square Guest House
# 6   manesar                       Hotel O RK
# 7   manesar         Hotel O Naveen Residancy
# 8   manesar                  Hotel O Rajhans
# 9   manesar          Hotel O K D Guest House
# 10  manesar           Hotel O Tulip Park Inn
# 11  manesar              Collection O Sakshi
# 12  manesar      Hotel O POP F Superhotel.in
# 13  manesar                  Capital O A-one
# 14  manesar         Hotel O Country Home Inn
# 15  manesar                      Hotel O Sky
# 16  manesar                     Hotel O Park
# 17  manesar              Hotel O Naveen Stay
# 18  manesar           Hotel O Mokiyana Hotel
# 19  manesar       Collection O Limewood Stay
#
# ...

# %%
mangalore= {
    'https://www.oyorooms.com/hotels-in-mangalore/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mangalore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mangalore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mangalore = pd.DataFrame(all_data)

# Display the DataFrame
mangalore
# Out:
#        Place                             Hotel Name  \
# 0  mangalore  Super Townhouse Oak Mangalore Central
# 1  mangalore                Collection O Nirvikalpa
# 2  mangalore           Capital O Sai Arya Residency
#
#                                          Destination Actual Price  \
# 0                              Kodailbail, Mangalore        ₹5961
# 1  Mathrushree Sai Grand View, Opposite Maruthi S...        ₹4978
# 2          Near Pumpwell Circle, Pumpwell, Mangalore        ₹6535
#
#   Offer Percentage  Price        Ratings     Review
# 0          67% off  ₹1624   (89 Ratings)  Very Good
# 1          67% off  ₹1319  (453 Ratings)  Very Good
# 2          67% off  ₹1743  (547 Ratings)  Excellent

# %%
mathura= {
    'https://www.oyorooms.com/hotels-in-mathura/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mathura:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mathura',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mathura = pd.DataFrame(all_data)

# Display the DataFrame
mathura
# Out:
#       Place                                         Hotel Name  \
# 0   mathura    Super Collection O Mathura Near Railway Station
# 1   mathura               Collection O Naroli Chowraha Mathura
# 2   mathura                                Hotel O Janam Bhumi
# 3   mathura  Super Hotel O Govind Nagar Near Krishan Janm B...
# 4   mathura                            Hotel O Dauji Residency
# 5   mathura             Super Hotel O Brij Gaurav Guest House
# 6   mathura                         SPOT ON JAYDEVI SEVA SADAN
# 7   mathura                               Hotel O Mayur Resort
# 8   mathura                           Hotel O Star Inn Highway
# 9   mathura                            SPOT ON CAFE THE HEAVEN
# 10  mathura                               Hotel O Dev paradise
# 11  mathura                           Hotel O Aniruddha Palace
# 12  mathura                         Hotel O Shree Radha Resort
# 13  mathura                             Hotel O shri ji garden
# ...

# %%
mcleod_ganj= {
    'https://www.oyorooms.com/hotels-in-mcleod_ganj/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mcleod_ganj:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mcleod_ganj',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mcleod_ganj = pd.DataFrame(all_data)

# Display the DataFrame
mcleod_ganj
# Out:
#          Place                                      Hotel Name  \
# 0  mcleod_ganj               Collection O Bhagsunag Mcleodganj
# 1  mcleod_ganj  Hotel O Snow Mountain Guest House & Restaurant
# 2  mcleod_ganj                           Hotel O SANDHYANA INN
#
#                                          Destination Actual Price  \
# 0              Near Vaishno Mata Mandir, Mcleod-Ganj        ₹3943
# 1               Near Sunset Point Naddi, Mcleod Ganj        ₹8305
# 2  Plot 3 Near Nature Feast Hotel Bhagsunag road ...        ₹7502
#
#   Offer Percentage  Price       Ratings     Review
# 0          73% off   ₹869  (44 Ratings)  Excellent
# 1          71% off  ₹1939   (3 Ratings)  Very Good
# 2          68% off  ₹1936   (9 Ratings)       Good

# %%
meerut= {
    'https://www.oyorooms.com/hotels-in-meerut/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in meerut:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'meerut',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
meerut = pd.DataFrame(all_data)

# Display the DataFrame
meerut
# Out:
#      Place                                         Hotel Name  \
# 0   meerut                         Hotel O Subhadra Residency
# 1   meerut                                  Hotel O Elibrista
# 2   meerut                                Hotel O Mukut Mahal
# 3   meerut                              Hotel O Kosha Resorts
# 4   meerut               Collection O The God's Palace Resort
# 5   meerut                                   HOTEL O TANISHQ
# 6   meerut                       Hotel O Meerut International
# 7   meerut                           SPOT ON Hotel Abhinandan
# 8   meerut                                  Hotel O Shubkamna
# 9   meerut                                  Hotel O Raj Mahal
# 10  meerut                           Super Hotel O Raj Palace
# 11  meerut                                 Hotel O Highway ON
# 12  meerut                          Hotel O Hmi International
# 13  meerut                                  Hotel O Relax Inn
# ...

# %%
mohali= {
    'https://www.oyorooms.com/hotels-in-mohali/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mohali:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mohali',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mohali = pd.DataFrame(all_data)

# Display the DataFrame
mohali
# Out:
#     Place                          Hotel Name  \
# 0  mohali  Clubhouse Hotel Chandigarh Mohali
# 1  mohali                      Hotel O Skyfox
# 2  mohali               Hotel O HC Mount View
# 3  mohali         Hotel O Spring Woods Suites
# 4  mohali             Hotel O Seventy stay in
# 5  mohali                      Hotel O Prince
# 6  mohali             Hotel O Karan Residency
# 7  mohali                Hotel O GG RESIDENCY
#
#                                         Destination Actual Price  \
# 0                                    Punjab, Mohali        ₹7170
# 1                                 Sector 57, Mohali        ₹2987
# 2                                 SAS Nagar, Mohali        ₹3091
# 3  On main street, Near SBI Bank, Sector 68, Mohali        ₹4534
# 4                                   17znull, Mohali        ₹3489
# 5                                 SAS Nagar, Mohali        ₹4853
# 6                Sahibzada Ajit Singh Nagar, Mohali        ₹4104
# ...

# %%
moradabad= {
    'https://www.oyorooms.com/hotels-in-moradabad/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in moradabad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'moradabad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
moradabad = pd.DataFrame(all_data)

# Display the DataFrame
moradabad
# Out:
#        Place                                 Hotel Name  \
# 0  moradabad                         Hotel O Vrinda Inn
# 1  moradabad                    Hotel O M K Guest House
# 2  moradabad                            Hotel O Diamond
# 3  moradabad                         HOTEL O KIGHT VIEW
# 4  moradabad                      Hotel O Prem Chunaria
# 5  moradabad                       Hotel Signature View
# 6  moradabad  Hotel O Glory green farms and guest house
# 7  moradabad                 Hotel O Knight guest house
# 8  moradabad                        Hotel O Rama Palace
# 9  moradabad                                Hotel O AVS
#
#                                        Destination Actual Price  \
# 0                     Gajraula (amroha), Moradabad        ₹1917
# 1                               Amroha , Moradabad        ₹4640
# 2                              Pin Code, Moradabad        ₹2353
# 3                             moradabad, Moradabad        ₹2338
# ...

# %%
motihari= {
    'https://www.oyorooms.com/hotels-in-motihari/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in motihari:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'motihari',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
motihari = pd.DataFrame(all_data)

# Display the DataFrame
motihari
# Out:
#       Place                               Hotel Name  \
# 0  motihari      Hotel O 813893 Hotel Siddhi Vinayak
# 1  motihari  Hotel O Siddhi Vinayak Hotel & Banquets
#
#                                          Destination Actual Price  \
# 0  Station Road Near Aditya Vision Motiharinull, ...        ₹3485
# 1                                 Motihari, Motihari        ₹3439
#
#   Offer Percentage Price        Ratings     Review
# 0          67% off  ₹916  (247 Ratings)  Very Good
# 1          72% off  ₹783  (453 Ratings)  Very Good

# %%
mumbai= {
    'https://www.oyorooms.com/hotels-in-mumbai/?page=7',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=6',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=5',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=4',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=3',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=2',
    'https://www.oyorooms.com/hotels-in-mumbai/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mumbai:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mumbai',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mumbai = pd.DataFrame(all_data)

# Display the DataFrame
mumbai
# Out:
#       Place                                         Hotel Name  \
# 0    mumbai                       Super Hotel O Sunrise Suites
# 1    mumbai        Hotel O Blue Inn Residence Near R City Mall
# 2    mumbai                                  Hotel O Sea View
# 3    mumbai  Hotel O Greenforest Near Airport Road Metro St...
# 4    mumbai                              Hotel O Global Spaces
# ..      ...                                                ...
# 135  mumbai                 Hotel O Tripthi Lodging & Boarding
# 136  mumbai   Hotel O Delight Inn Near Andheri Railway Station
# 137  mumbai                            Hotel Orange Residency
# 138  mumbai                          Super Hotel O Fortuna Inn
# 139  mumbai                    Super Capital O Hotel Konar Inn
#
#                                            Destination Actual Price  \
# 0                                     Mumbai- , Mumbai        ₹8524
# 1    Kailash Industrial Complex, near Kailash Busin...        ₹6188
# ...

# %%
mussoorie= {
    'https://www.oyorooms.com/hotels-in-mussoorie/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mussoorie:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mussoorie',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mussoorie = pd.DataFrame(all_data)

# Display the DataFrame
mussoorie
# Out:
#         Place                                         Hotel Name  \
# 0   mussoorie                               Palette Bhatta Falls
# 1   mussoorie               Hotel O Kempty Lake Adventure Resort
# 2   mussoorie             Townhouse Mall Road Near Library Chowk
# 3   mussoorie  Super Collection O Mall Road Near St. Georges ...
# 4   mussoorie                                  Hotel O Pine Tree
# 5   mussoorie                         Super Collection O Pioneer
# 6   mussoorie                      Hotel O Sukoon Hotel & Resort
# 7   mussoorie                                Hotel O Sri Narayan
# 8   mussoorie                  Collection O The Perfect Hide Out
# 9   mussoorie           Hotel O Sherawali Restaurant & Home Stay
# 10  mussoorie                       Collection O Grey Castle Inn
# 11  mussoorie                               Collection O Sapling
# 12  mussoorie                             Hotel O Cozy Home Stay
# ...

# %%
mysore= {
    'https://www.oyorooms.com/hotels-in-mysore/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in mysore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'mysore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
mysore = pd.DataFrame(all_data)

# Display the DataFrame
mysore
# Out:
#      Place                                         Hotel Name  \
# 0   mysore                      Super Townhouse Hebbal Mysore
# 1   mysore                       Collection O The Olive Shine
# 2   mysore       Townhouse Mysore Central formerly Olive Star
# 3   mysore                           Townhouse Mysore Central
# 4   mysore                   Super Hotel O Kaveri Road Mysore
# 5   mysore  Hotel O Vijaya Nagar Mysore formerly SRK Paradise
# 6   mysore                         Hotel O Kingston Residency
# 7   mysore  Super Townhouse Mysore City Centre Formerly Ho...
# 8   mysore  Townhouse City Center Near Mysore Palace forme...
# 9   mysore  Super Collection O Rajkumar Road formerly Ston...
# 10  mysore                    Collection O Emara Grand Mysore
# 11  mysore                           Hotel O Jeevan Residency
# 12  mysore                               Hotel O Indra Suites
# 13  mysore                             Hotel O Indra Comforts
# ...

# %%
nagpur= {
    'https://www.oyorooms.com/hotels-in-nagpur/?page=7',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=6',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=5',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=4',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=3',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=2',
    'https://www.oyorooms.com/hotels-in-nagpur/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in nagpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'nagpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
nagpur = pd.DataFrame(all_data)

# Display the DataFrame
nagpur
# Out:
#       Place                      Hotel Name  \
# 0    nagpur        Hotel O Airport Imperial
# 1    nagpur             Hotel O Yashraj Inn
# 2    nagpur           Hotel O Pritesh Grand
# 3    nagpur                  Hotel O Oshnik
# 4    nagpur          Hotel O Basera Lodging
# ..      ...                             ...
# 125  nagpur  Hotel O Seva Service Apartment
# 126  nagpur         Hotel O R K Guest House
# 127  nagpur          Hotel O Pritesh Deluxe
# 128  nagpur  Super Collection O Hingna Road
# 129  nagpur      Super Hotel O Manish Nagar
#
#                                            Destination Actual Price  \
# 0                               Modern Society, Nagpur        ₹3561
# 1                                    Bahadura , Nagpur        ₹2458
# 2                        Near Sp Public School, Nagpur        ₹3069
# 3       Bidgaon Tarif RdBidgaon Tarodi T Point, Nagpur        ₹4911
# 4              Infront of Reliance petrol Pump, Nagpur        ₹3077
# ...

# %%
namakkal= {
    'https://www.oyorooms.com/hotels-in-namakkal/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in namakkal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'namakkal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
namakkal = pd.DataFrame(all_data)

# Display the DataFrame
namakkal
# Out:
#       Place               Hotel Name                      Destination  \
# 0  namakkal   Super Hotel O Namakkal             Salem Road, Namakkal
# 1  namakkal  Hotel O Royal Residency  Near Anjaneyar Temple, Namakkal
#
#   Actual Price Offer Percentage  Price        Ratings     Review
# 0        ₹3624          68% off   ₹957  (327 Ratings)  Excellent
# 1        ₹4702          68% off  ₹1208  (336 Ratings)       Good

# %%
narnaul= {
    'https://www.oyorooms.com/hotels-in-narnaul/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in narnaul:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'narnaul',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
narnaul = pd.DataFrame(all_data)

# Display the DataFrame
narnaul
# Out:
#       Place                           Hotel Name  \
# 0   narnaul                  Hotel O Suraj Villa
# 1   narnaul                  Hotel O City Palace
# 2   narnaul                          Hotel O Raj
# 3   narnaul                        Hotel O KBS-G
# 4   narnaul            Hotel O Blue Dream Palace
# 5   narnaul              Hotel O Cora Vila Hotel
# 6   narnaul                 Hotel O Vihan Palace
# 7   narnaul                     Hotel O MS Hotel
# 8   narnaul                    Hotel O Rao Hotel
# 9   narnaul  Hotel O The Dream Restaurant & Cafe
# 10  narnaul                     Hotel O Rockland
# 11  narnaul         SPOT ON 83131 Saini Property
# 12  narnaul                 Hotel O Kanish Place
#
#                                           Destination Actual Price  \
# 0                               Mahendragarh, Narnaul        ₹2137
# 1                  fast flowers  CSD canteen, Narnaul        ₹2315
# 2                               Mahendragarh, Narnaul        ₹2249
# ...

# %%
nashik= {
    'https://www.oyorooms.com/hotels-in-nashik/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in nashik:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'nashik',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
nashik = pd.DataFrame(all_data)

# Display the DataFrame
nashik
# Out:
#      Place                                         Hotel Name  \
# 0   nashik  Super Hotel O Nashik Road formerly The Address...
# 1   nashik                               Super Hotel O Nashik
# 2   nashik  Hotel O Nashik Near Vijay Mamta Theatre former...
# 3   nashik                                   Hotel O Paradise
# 4   nashik                        Super Hotel O Saubhagya Inn
# 5   nashik                           Collection O Rama Palace
# 6   nashik                       Hotel O 10671 Hotel Sai Prem
# 7   nashik                                   Hotel O Food Hub
# 8   nashik                           Hotel O LAKEBEALE RESORT
# 9   nashik                               Super Hotel O Saroj
# 10  nashik                           Hotel O Sachin Residency
#
#                                           Destination Actual Price  \
# 0          Near Bytco Hospital, Rajwada Nagar, Nashik        ₹5951
# 1     Opposite Inox theatre, Nashik-Pune Road, Nashik        ₹6597
# ...

# %%
navi_mumbai= {
    'https://www.oyorooms.com/hotels-in-navi_mumbai/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in navi_mumbai:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'navi_mumbai',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
navi_mumbai = pd.DataFrame(all_data)

# Display the DataFrame
navi_mumbai
# Out:
#          Place                            Hotel Name  \
# 0  navi_mumbai                Hotel O Nirsukh Palace
# 1  navi_mumbai  Collection O Guru Heritage Kalamboli
#
#                                 Destination Actual Price Offer Percentage  \
# 0                 Near Kopra Bridge, Mumbai        ₹5789          72% off
# 1  Near Gurukrupa heritage, Kamothe, Mumbai        ₹4992          72% off
#
#    Price        Ratings Review
# 0  ₹1328  (221 Ratings)   Good
# 1  ₹1139  (348 Ratings)   Good

# %%
noida= {
    'https://www.oyorooms.com/hotels-in-noida/?page=11',
    'https://www.oyorooms.com/hotels-in-noida/?page=10',
    'https://www.oyorooms.com/hotels-in-noida/?page=9',
    'https://www.oyorooms.com/hotels-in-noida/?page=8',
    'https://www.oyorooms.com/hotels-in-noida/?page=7',
    'https://www.oyorooms.com/hotels-in-noida/?page=6',
    'https://www.oyorooms.com/hotels-in-noida/?page=5',
    'https://www.oyorooms.com/hotels-in-noida/?page=4',
    'https://www.oyorooms.com/hotels-in-noida/?page=3',
    'https://www.oyorooms.com/hotels-in-noida/?page=2',
    'https://www.oyorooms.com/hotels-in-noida/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in noida:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'noida',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
noida = pd.DataFrame(all_data)

# Display the DataFrame
noida
# Out:
#      Place                                         Hotel Name  \
# 0    noida                         Townhouse Sector 135 Noida
# 1    noida               Super Townhouse Oak Sector 116 Noida
# 2    noida  Super Collection O Sector 55 Noida Near Noida ...
# 3    noida              Collection O Ratiram Palace BY Wamson
# 4    noida                               Super Hotel O Wamson
# ..     ...                                                ...
# 215  noida                            Collection O Apple Tree
# 216  noida                                  Hotel O Relax Inn
# 217  noida                              Hotel O YAMUNA RESORT
# 218  noida                            Hotel O Golden Imperial
# 219  noida                              Hotel O The Royal Inn
#
#                                            Destination Actual Price  \
# 0                           Gautam Buddha Nagar, Noida        ₹4004
# 1                                    Sector 116, Noida        ₹5459
# ...

# %%
ooty= {
    'https://www.oyorooms.com/hotels-in-ooty/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ooty:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ooty',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ooty = pd.DataFrame(all_data)

# Display the DataFrame
ooty
# Out:
#   Place                                         Hotel Name  \
# 0  ooty                Super Hotel O Ooty Near Rose Garden
# 1  ooty                        Collection O Udhagamandalam
# 2  ooty  Super Hotel O Vijaynagar Road formerly Anmol P...
# 3  ooty                       Super Townhouse Hills Palace
# 4  ooty                    Collection O Charing Cross Ooty
#
#                                Destination Actual Price Offer Percentage  \
# 0                           Nilgiris, Ooty        ₹5368          67% off
# 1                   Near Ooty Market, Ooty        ₹4934          71% off
# 2  Near Maruti Suzuki Service Center, Ooty        ₹4444          68% off
# 3   Near Charing Cross, Udagamandalm, Ooty        ₹5212          67% off
# 4                      Charing Cross, Ooty        ₹4712          71% off
#
#    Price        Ratings     Review
# 0  ₹1482  (249 Ratings)   Fabulous
# 1  ₹1161  (624 Ratings)   Fabulous
# 2  ₹1171  (243 Ratings)  Excellent
# ...

# %%
pachmarhi= {
    'https://www.oyorooms.com/hotels-in-pachmarhi/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in pachmarhi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'pachmarhi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
pachmarhi = pd.DataFrame(all_data)

# Display the DataFrame
pachmarhi
# Out:
#        Place                                 Hotel Name  \
# 0  pachmarhi  Super Collection O Arvind Marg Pachamarhi
# 1  pachmarhi           Townhouse Arvind Marg Pachamarhi
# 2  pachmarhi                    SPOT ON Pachmarhi Hills
#
#                         Destination Actual Price Offer Percentage  Price  \
# 0            Arvind Marg, Pachmarhi        ₹4689          73% off  ₹1070
# 1            Arvind Marg, Pachmarhi        ₹5547          68% off  ₹1465
# 2  Madhya Pradesh 461881, Pachmarhi        ₹9979          70% off  ₹2447
#
#         Ratings     Review
# 0  (27 Ratings)  Excellent
# 1  (36 Ratings)  Excellent
# 2  (30 Ratings)  Excellent

# %%
pathanamthitta= {
    'https://www.oyorooms.com/hotels-in-pathanamthitta/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in pathanamthitta:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'pathanamthitta',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
pathanamthitta = pd.DataFrame(all_data)

# Display the DataFrame
pathanamthitta
# Out:
#             Place        Hotel Name               Destination Actual Price  \
# 0  pathanamthitta  Hotel O VR Lodge  Nooranad, Pathanamthitta        ₹2697
#
#   Offer Percentage Price       Ratings     Review
# 0          72% off  ₹606  (20 Ratings)  Very Good

# %%
patiala= {
    'https://www.oyorooms.com/hotels-in-patiala/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in patiala:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'patiala',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
patiala = pd.DataFrame(all_data)

# Display the DataFrame
patiala
# Out:
#      Place                   Hotel Name  \
# 0  patiala           Hotel O Kaka Hotel
# 1  patiala    Super Hotel O Blossom Inn
# 2  patiala            Hotel O New Delhi
# 3  patiala     Super Hotel O Grand Polo
# 4  patiala  Hotel O Patiala Guest House
#
#                                          Destination Actual Price  \
# 0                  Near Mall Road, Baradari, Patiala        ₹2778
# 1                   Near Punjabi University, Patiala        ₹2515
# 2  Plot Number 7,Behind Urban Estate Phase-2, Sha...        ₹3382
# 3                             Walia Enclave, Patiala        ₹3641
# 4  JP Market, Near Punjabi University, Rajpura Ro...        ₹2938
#
#   Offer Percentage Price        Ratings     Review
# 0          71% off  ₹626    (9 Ratings)  Very Good
# 1          71% off  ₹578  (234 Ratings)  Very Good
# 2          72% off  ₹756   (50 Ratings)  Very Good
# 3          71% off  ₹831   (38 Ratings)  Very Good
# 4          71% off  ₹664   (28 Ratings)  Very Good

# %%
patna= {
    'https://www.oyorooms.com/hotels-in-patna/?page=6',
    'https://www.oyorooms.com/hotels-in-patna/?page=5',
    'https://www.oyorooms.com/hotels-in-patna/?page=4',
    'https://www.oyorooms.com/hotels-in-patna/?page=3',
    'https://www.oyorooms.com/hotels-in-patna/?page=2',
    'https://www.oyorooms.com/hotels-in-patna/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in patna:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'patna',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
patna = pd.DataFrame(all_data)

# Display the DataFrame
patna
# Out:
#      Place                                         Hotel Name  \
# 0    patna                                     Hotel O Kamini
# 1    patna                        Hotel O Sneh Inn RMS Colony
# 2    patna                                  Hotel O Home Town
# 3    patna                                Hotel O Westend Inn
# 4    patna                           Collection O Dream Villa
# ..     ...                                                ...
# 115  patna                            Super Hotel O Mahal Inn
# 116  patna                                  Hotel O Dream Inn
# 117  patna                    Hotel O 825004 Hotel Savera Inn
# 118  patna  Super Collection O Rajendra Path Near Railway ...
# 119  patna                        Super Hotel O Relax Rainbow
#
#                                            Destination Actual Price  \
# 0                                   Boring Road, Patna        ₹3318
# 1    Plot No 1039 RMS Colony Main Road Jaganpura Mo...        ₹2634
# ...

# %%
pondicherry= {
    'https://www.oyorooms.com/hotels-in-pondicherry/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in pondicherry:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'pondicherry',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
pondicherry = pd.DataFrame(all_data)

# Display the DataFrame
pondicherry
# Out:
#           Place                                         Hotel Name  \
# 0   pondicherry                        Super Townhouse Pondicherry
# 1   pondicherry        Super Hotel O Heritage Town formerly Vasavi
# 2   pondicherry         Super Townhouse Vanur Near Auroville Beach
# 3   pondicherry                 Collection O Auroville Pondicherry
# 4   pondicherry         Super Hotel O Thavalakuppam Near Bus Stand
# 5   pondicherry                                    Hotel O Lawspet
# 6   pondicherry         Super Townhouse White Town Near Rock Beach
# 7   pondicherry  Super Hotel O White Town formerly Seascape Res...
# 8   pondicherry  Hotel O Home Le Bliss Hotels ,3 Mins Walk From...
# 9   pondicherry                         Super Collection O Mgr Inn
# 10  pondicherry                      Super Hotel O Om Sakthi Hotel
# 11  pondicherry                                    Grand Ocean Inn
# 12  pondicherry                             Hotel O PARAM HOMESTAY
# ...

# %%
blair= {
    'https://www.oyorooms.com/hotels-in-port-blair/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in blair:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'blair',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
blair = pd.DataFrame(all_data)

# Display the DataFrame
blair
# Out:
#    Place                   Hotel Name  \
# 0  blair                 Hotel O Nico
# 1  blair            Hotel O P S Grand
# 2  blair     Hotel O V Knot Residency
# 3  blair         Hotel O Matri Smriti
# 4  blair          Hotel O Arasi Hotel
# 5  blair              Hotel O Sunrise
# 6  blair               Hotel O Aashna
# 7  blair  Hotel O A G Residency & Son
#
#                                          Destination Actual Price  \
# 0             Andaman and Nicobar Island, Port-Blair        ₹5507
# 1  Near International Airport, Jungli ghat, Port-...        ₹5094
# 2       Near Kalapani Museum, Garacharma, Port-Blair        ₹7452
# 3       Near Rangat Bus Terminal, Rangat, Port-Blair        ₹7081
# 4            Plot 22-Nayagaon Port Blair, Port-Blair        ₹6445
# 5                        Near Bathubasti, Port-Blair        ₹8999
# 6       Near Atm Axis, Mayabunder, Andaman & Nicobar        ₹7401
# 7  Near Garacharma Hospital, Bhathu Basti, Port B...        ₹6659
#
# ...

# %%
pune= {
    'https://www.oyorooms.com/hotels-in-pune/?page=9',
    'https://www.oyorooms.com/hotels-in-pune/?page=8',
    'https://www.oyorooms.com/hotels-in-pune/?page=7',
    'https://www.oyorooms.com/hotels-in-pune/?page=6',
    'https://www.oyorooms.com/hotels-in-pune/?page=5',
    'https://www.oyorooms.com/hotels-in-pune/?page=4',
    'https://www.oyorooms.com/hotels-in-pune/?page=3',
    'https://www.oyorooms.com/hotels-in-pune/?page=2',
    'https://www.oyorooms.com/hotels-in-pune/?page=1'
    
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in pune:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'pune',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
pune = pd.DataFrame(all_data)

# Display the DataFrame
pune
# Out:
#     Place                                         Hotel Name  \
# 0    pune                      Hotel O Silver Star Executive
# 1    pune                                  Hotel O Sai Lodge
# 2    pune                          Hotel O Manav Shree Lodge
# 3    pune                          Hotel O Kanha Inn Lodging
# 4    pune                           Hotel O Galaxy Near INOX
# ..    ...                                                ...
# 175  pune              Super Collection O Sunshine Near Inox
# 176  pune  Super Hotel O RK's Regency Near Navale Hospita...
# 177  pune                          Super Collection O Rk Inn
# 178  pune                                 Hotel O Arusai Inn
# 179  pune                           Super Townhouse Balewadi
#
#                                            Destination Actual Price  \
# 0    Near Mcdonald'S, Wadgaon Budruk-Narhe Road,Pun...        ₹4065
# 1                                         bahule, Pune        ₹3371
# ...

# %%
puri= {
    'https://www.oyorooms.com/hotels-in-puri/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in puri:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'puri',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
puri = pd.DataFrame(all_data)

# Display the DataFrame
puri
# Out:
#    Place                                         Hotel Name  \
# 0   puri                  Super Townhouse Near Marine Drive
# 1   puri                   Hotel O Shri Jagannath Homestay
# 2   puri                       Palette Shree Jagannath Puri
# 3   puri  Super Collection O Paschim Dwar Near Jagannath...
# 4   puri       Super Hotel O Jagannatha Temple Paschim Dwar
# 5   puri  Super Hotel O Sarvodaya Nagar Near Railway Sta...
# 6   puri  Super Hotel O Dakshin Dwar formerly Radha Kris...
# 7   puri                            Super Hotel O Sai Leela
# 8   puri                                  HOTEL O NADAMBIKA
# 9   puri                                  Hotel O Dev Bhumi
# 10  puri                                    Hotel O Planet9
# 11  puri                         Hotel O Jagannath Heritage
# 12  puri                       Super Hotel O The Brightstar
# 13  puri                                Hotel O VENTURE INN
# 14  puri                             Hotel O Sai Balaji Inn
# ...

# %%
raipur= {
    'https://www.oyorooms.com/hotels-in-raipur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in raipur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'raipur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
raipur = pd.DataFrame(all_data)

# Display the DataFrame
raipur
# Out:
#      Place                                         Hotel Name  \
# 0   raipur  Super Hotel O Jaistambh Chowk formerly Guru Kirpa
# 1   raipur                            Collection O Ns Sheetal
# 2   raipur                               Super Hotel O Raipur
# 3   raipur     Townhouse NIT Raipur Formerly Hotel City Pride
# 4   raipur                                  Hotel Supreet Inn
# 5   raipur  Super Hotel O Raipur Railway Station formerly ...
# 6   raipur                                 Hotel O Pragya New
# 7   raipur                                  Hotel O SS Palace
# 8   raipur  Hotel O Raipur City Center formerly Hotel Sout...
# 9   raipur                               Hotel O Currency Inn
# 10  raipur  Super Hotel O Bhaisthan Near Railway Station F...
# 11  raipur                               Hotel O Gyan Regency
# 12  raipur                                  Hotel O PV Palace
# 13  raipur                     SPOT ON Hotel SB Air Port Stay
# ...

# %%
rajahmundry= {
    'https://www.oyorooms.com/hotels-in-rajahmundry/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in rajahmundry:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'rajahmundry',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
rajahmundry = pd.DataFrame(all_data)

# Display the DataFrame
rajahmundry
# Out:
#          Place                   Hotel Name  \
# 0  rajahmundry    Hotel O Bommana Residency
# 1  rajahmundry  Super Townhouse Rajahmundry
# 2  rajahmundry          Hotel O Seera Grand
# 3  rajahmundry        Hotel O Seera Enclave
# 4  rajahmundry   Hotel O Parnasala Princely
#
#                                          Destination Actual Price  \
# 0             Near Srikanya Grand Hotel, Rajahmundry        ₹3397
# 1              Near Kotipalli Bus Stand, Rajahmundry        ₹8444
# 2                 stadium roadInnespeta, Rajahmundry        ₹4104
# 3    Near Oak wood school, Diwancheruvu, Rajahmundry        ₹4229
# 4  Near City Union Bank, Tyagaraja Nagar, Rajahmu...        ₹3681
#
#   Offer Percentage  Price        Ratings     Review
# 0          72% off   ₹749  (183 Ratings)       Good
# 1          67% off  ₹2300  (130 Ratings)   Fabulous
# 2          72% off   ₹940   (20 Ratings)       Good
# 3          68% off  ₹1072  (182 Ratings)  Very Good
# ...

# %%
rajkot= {
    'https://www.oyorooms.com/hotels-in-rajkot/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in rajkot:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'rajkot',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
rajkot = pd.DataFrame(all_data)

# Display the DataFrame
rajkot
# Out:
#     Place                                         Hotel Name  \
# 0  rajkot                             Hotel O H.R.KING HOTEL
# 1  rajkot  Super Collection O Limda Chowk formerly Hotel ...
# 2  rajkot                                  Hotel O Surya Dev
# 3  rajkot                                    Hotel O Capital
# 4  rajkot                                  Hotel O Royal Raj
# 5  rajkot                                     hotel O kalyan
# 6  rajkot                                       Hotel Velvet
# 7  rajkot           Super Collection O Simran Raghuveer Para
# 8  rajkot                                   Hotel O Park Inn
# 9  rajkot                               Hotel O Royal Season
#
#                                          Destination Actual Price  \
# 0                               Bhakti Nagar, Rajkot        ₹2945
# 1              Near Limda Chowk, Limda Chowk, Rajkot        ₹5866
# 2      old marking yard near garden fariland, Rajkot        ₹2630
# ...

# %%
ranchi= {
    'https://www.oyorooms.com/hotels-in-ranchi/?page=3',
    'https://www.oyorooms.com/hotels-in-ranchi/?page=2',
    'https://www.oyorooms.com/hotels-in-ranchi/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ranchi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ranchi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ranchi = pd.DataFrame(all_data)

# Display the DataFrame
ranchi
# Out:
#      Place                                        Hotel Name  \
# 0   ranchi                       Hotel O Oxy Hotel Dream Inn
# 1   ranchi                    Hotel O AURA HOTEL SONNET INNS
# 2   ranchi                                  Hotel O Snug Inn
# 3   ranchi                       HOTEL O SHIVA RESIDENCY INN
# 4   ranchi                                  Townhouse Marina
# 5   ranchi                          Hotel O Park Street Inn
# 6   ranchi  Super Collection O Aura Hotel Rajdhani Residency
# 7   ranchi                               Super Hotel O SK IN
# 8   ranchi                  Super Hotel O Hill Top & Banquet
# 9   ranchi                      Super Hotel O Prashant Villa
# 10  ranchi                        Hotel O MANI RESIDENCY INN
# 11  ranchi                              Hotel O Jagat Palace
# 12  ranchi          Super Hotel O 67309 Hotel Tuk Tuk Palace
# 13  ranchi                      Super Hotel O The Radium Inn
# ...

# %%
rewari= {
    'https://www.oyorooms.com/hotels-in-rewari/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in rewari:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'rewari',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
rewari = pd.DataFrame(all_data)

# Display the DataFrame
rewari
# Out:
#      Place                                         Hotel Name  \
# 0   rewari                           SPOT ON Hotel Luv Palace
# 1   rewari           Hotel O Kanode Gate formerly Hotel Dhruv
# 2   rewari  Super Hotel O Ambedkar Chowk Rewari formerly H...
# 3   rewari                              Hotel O TheTaj Palace
# 4   rewari                          Hotel O DELIGHT INN HOTEL
# 5   rewari                              Hotel O Friends Hotel
# 6   rewari  Hotel O Virat Inn, Siha, Tehsil Khol, Opposite...
# 7   rewari            Hotel O Yadav Restaurant & Family Rooms
# 8   rewari                   Hotel O Rock Star Hotal And Room
# 9   rewari                         Hotel O INDRA FUN 'N' FOOD
# 10  rewari                            Hotel O Parth Logistics
# 11  rewari                                    The Lotus Hotel
# 12  rewari                                Hotel O Deep Palace
# 13  rewari                              Hotel O Thikana Hotel
# ...

# %%
rishikesh= {
    'https://www.oyorooms.com/hotels-in-rishikesh/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in rishikesh:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'rishikesh',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
rishikesh = pd.DataFrame(all_data)

# Display the DataFrame
rishikesh
# Out:
#         Place                                    Hotel Name  \
# 0   rishikesh                   Super Townhouse Oak Tapovan
# 1   rishikesh                       Super Townhouse Tapovan
# 2   rishikesh          Super Hotel O Badrinath Road Tapovan
# 3   rishikesh         Hotel O Balaknath Temple Road Tapovan
# 4   rishikesh                              Hotel O Neu-Nest
# 5   rishikesh            Hotel O Tapovan Near Deacon Valley
# 6   rishikesh  Super Hotel O Tapovan Rise cottages and cafe
# 7   rishikesh                        Hotel O Chandra palace
# 8   rishikesh                      Hotel O Ayansh Residency
# 9   rishikesh              Hotel O Rajaji wild trail Resort
# 10  rishikesh                       Hotel O Rishikesh Stay
# 11  rishikesh             Collection O Namo stays Rishikesh
# 12  rishikesh                         Collection O KEDAR IN
# 13  rishikesh                         Hotel O Krishna Rooms
# 14  rishikesh                     Collection O Ak Residency
# ...

# %%
rohtak= {
    'https://www.oyorooms.com/hotels-in-rohtak/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in rohtak:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'rohtak',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
rohtak = pd.DataFrame(all_data)

# Display the DataFrame
rohtak
# Out:
#      Place                                         Hotel Name  \
# 0   rohtak                  Super Townhouse Model Town Rohtak
# 1   rohtak  Super Collection O Roop Vihar Rohtak formerly ...
# 2   rohtak                                     Hotel O Grapes
# 3   rohtak                                   Hotel O Landlord
# 4   rohtak                          Hotel O Vivaan Residency
# 5   rohtak                                        Hotel O Raj
# 6   rohtak                                        Spot On the
# 7   rohtak                        Hotel O J7 Hotel & Banquets
# 8   rohtak                                    Hotel O A Hotel
# 9   rohtak                      Hotel O The Angel Guest House
# 10  rohtak                            Hotel O POP Lucky Hotel
# 11  rohtak                            Hotel O Highway Haveli
# 12  rohtak                   Hotel O POP HOME A Suneja Empire
# 13  rohtak                              Hotel O SunRise Hotel
# ...

# %%
salem= {
    'https://www.oyorooms.com/hotels-in-salem/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in salem:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'salem',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
salem = pd.DataFrame(all_data)

# Display the DataFrame
salem
# Out:
#    Place                Hotel Name  \
# 0  salem   Hotel O Royal Residency
# 1  salem  Hotel O Vedha Residency
# 2  salem          Hotel O RK HOTEL
# 3  salem           Hotel O Maruthi
# 4  salem        Hotel O Gala Vista
#
#                                          Destination Actual Price  \
# 0  Near ARSS multiplex complex, Angammal Colony, ...        ₹3784
# 1                               Tharamangalam, Salem        ₹3761
# 2                                       Salem, Salem        ₹3307
# 3                   Near Salem Old Bus Stand, Salem         ₹1789
# 4                      Near new Bus standnull, Salem        ₹3640
#
#   Offer Percentage Price        Ratings     Review
# 0          71% off  ₹892  (332 Ratings)       Good
# 1          74% off  ₹771    (4 Ratings)   Fabulous
# 2          72% off  ₹748   (27 Ratings)       Fair
# 3          70% off  ₹419  (216 Ratings)  Very Good
# 4          74% off  ₹741  (147 Ratings)       Fair

# %%
satna= {
    'https://www.oyorooms.com/hotels-in-satna/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in satna:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'satna',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
satna = pd.DataFrame(all_data)

# Display the DataFrame
satna
# Out:
#    Place                              Hotel Name  \
# 0  satna                   Hotel O Fairyland Inn
# 1  satna  Hotel O A Dream Residency & Restaurant
# 2  satna                        HOTEL O CAPITAL
# 3  satna                    Hotel O Sunset Lodge
# 4  satna                    SPOT ON Bharat Lodge
# 5  satna                   SPOT ON Satguru Lodge
#
#                                          Destination Actual Price  \
# 0                    purana power house chowk, Satna        ₹3701
# 1  01 011 Gayatri Nagar Chritukula chowk E pateri...        ₹3048
# 2                                    Satna MP, Satna           NA
# 3                                  Panna Naka, Satna           NA
# 4                           Krishna nagarnull, Satna           NA
# 5  Nearby Landmark- 70 meters from Railway Statio...           NA
#
#   Offer Percentage Price       Ratings     Review
# 0          74% off  ₹770  (77 Ratings)       Good
# 1          71% off  ₹691  (20 Ratings)  Excellent
# ...

# %%
shillong= {
    'https://www.oyorooms.com/hotels-in-shillong/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in shillong:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'shillong',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
shillong = pd.DataFrame(all_data)

# Display the DataFrame
shillong
# Out:
#       Place                                         Hotel Name  \
# 0  shillong                               Super Hotel O Rynjah
# 1  shillong                 Super Hotel O Am Bed And Breakfast
# 2  shillong  Super Hotel O Shillong formerly Balaji Guest H...
# 3  shillong                        Super Hotel O Pillars House
# 4  shillong                      Hotel O Evergreen Guest House
# 5  shillong                          Hotel O Lapalang Shillong
# 6  shillong                             Hotel O Bamon Homestay
# 7  shillong                                 Hotel O Knight Inn
#
#                                          Destination Actual Price  \
# 0                        R R Colony, Rynjah,Shillong        ₹5684
# 1                    Near Lower Lachumiere, Shillong        ₹6454
# 2                Near Passport Sewa Kendra, Shillong        ₹6309
# 3           Near Hari Har Dairy, Garikhana, Shillong        ₹5567
# ...

# %%
shimla= {
    'https://www.oyorooms.com/hotels-in-shimla/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in shimla:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'shimla',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
shimla = pd.DataFrame(all_data)

# Display the DataFrame
shimla
# Out:
#     Place                                      Hotel Name  \
# 0  shimla   Townhouse Oak ISBT formerly the Hotel Horizon
# 1  shimla   Super Townhouse Kachighati formely Palm Bliss
# 2  shimla                            Hotel O Tara Regency
# 3  shimla       Sunday Premium 5 BHK Villa Mihika, Shimla
# 4  shimla                                  Hotel O Unique
# 5  shimla             Hotel O HOME 81250D Abhiaak Regency
#
#                                          Destination Actual Price  \
# 0                                Boileauganj, Shimla        ₹5374
# 1                                Kachighatti, Shimla        ₹4767
# 2                                   Taradevi, Shimla        ₹4835
# 3                                      Kufri, Shimla        ₹4028
# 4  Below The National Flag Ridge Shimla/Opposite ...        ₹8298
# 5                                     Shimla, Shimla           NA
#
#   Offer Percentage  Price        Ratings     Review
# ...

# %%
shirdi= {
    'https://www.oyorooms.com/hotels-in-shirdi/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in shirdi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'shirdi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
shirdi = pd.DataFrame(all_data)

# Display the DataFrame
shirdi
# Out:
#      Place                                         Hotel Name  \
# 0   shirdi        Super Hotel O Datta Nagar formerly Baba Sai
# 1   shirdi           Collection O Shirdi Near Sai Baba Temple
# 2   shirdi  Hotel O Palkhi Road Near Sai Baba Temple forme...
# 3   shirdi                          Hotel O Chhatrapati Nagar
# 4   shirdi    Collection O Shirdi Midtown formerly Sai Sanket
# 5   shirdi                                Collection O Shirdi
# 6   shirdi                             Hotel O Shirdi Sai Inn
# 7   shirdi                              Collection O Paradise
# 8   shirdi                            Collection O Satyan Inn
# 9   shirdi                           Townhouse Classio Suites
# 10  shirdi                          Hotel O Sai Prasad Resort
# 11  shirdi                  SPOT ON Hotel Sai Jeeva Residency
# 12  shirdi                         Collection O Reeva Regency
# 13  shirdi                                  Hotel O Sai Sakha
# ...

# %%
siliguri= {
    'https://www.oyorooms.com/hotels-in-siliguri/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in siliguri:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'siliguri',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
siliguri = pd.DataFrame(all_data)

# Display the DataFrame
siliguri
# Out:
#        Place                                         Hotel Name  \
# 0   siliguri  Super Hotel O Champasari Siliguri formerly Fou...
# 1   siliguri  Super Hotel O Pradhan Nagar Siliguri Formerly ...
# 2   siliguri                           Hotel O UTTARA RESIDENCY
# 3   siliguri                          Super Capital O Priyanshu
# 4   siliguri                         Hotel O Smriti Guest House
# 5   siliguri                Collection O Hotel Danish Dreamstay
# 6   siliguri                Super Hotel O Kings Hotel & Banquet
# 7   siliguri                       Collection O Palm Tree Lodge
# 8   siliguri                          Collection O Roadside Inn
# 9   siliguri                          Hotel O Central Courtyard
# 10  siliguri                             Hotel O Golden Moments
# 11  siliguri                           Collection O Relax Hotel
# 12  siliguri                               Hotel O Air Link Inn
#
# ...

# %%
sirsa= {
    'https://www.oyorooms.com/hotels-in-sirsa/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in sirsa:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'sirsa',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
sirsa = pd.DataFrame(all_data)

# Display the DataFrame
sirsa
# Out:
#    Place                               Hotel Name  \
# 0  sirsa  Super Hotel O Sirsa Hotel & Guest House
# 1  sirsa              Hotel O The Heritage Palace
# 2  sirsa                   Hotel O Sirsa City Inn
#
#                                  Destination Actual Price Offer Percentage  \
# 0                               Sirsa, Sirsa        ₹2785          71% off
# 1  Near HP Petrol Pump, Farwain Kalan, Sirsa        ₹2837          71% off
# 2          Near Sirsa Bus Stand, MITC, Sirsa        ₹3321          68% off
#
#   Price       Ratings     Review
# 0  ₹623  (88 Ratings)  Very Good
# 1  ₹661   (9 Ratings)       Good
# 2  ₹844  (47 Ratings)       Fair

# %%
sitapur= {
    'https://www.oyorooms.com/hotels-in-sitapur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in sitapur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'sitapur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
sitapur = pd.DataFrame(all_data)

# Display the DataFrame
sitapur
# Out:
#      Place                     Hotel Name  \
# 0  sitapur               Super Hotel O SK
# 1  sitapur   Collection O Nimisha Jail Rd
# 2  sitapur  Super Hotel O Ranjana Diamond
# 3  sitapur           Hotel O Kashvi Hotel
# 4  sitapur          HOTEL O S.R GRAND INN
# 5  sitapur               Hotel O SK Grand
# 6  sitapur                  HOTEL O SHYAM
#
#                                          Destination Actual Price  \
# 0  Near DELHIVERY OFFICEGANDHINAGAR UTTARI KASBA ...        ₹2344
# 1                  Near Bada Hanuman Mandir, Sitapur        ₹4369
# 2  H.No H181 opposite block office near Indian Ba...        ₹2595
# 3                                  Gauvapur, Sitapur        ₹2912
# 4             Near Indian BankLaharpur Road, Sitapur        ₹3419
# 5                                   Sitapur, Sitapur        ₹3851
# 6  Plot no. 22 Village MAU Near HP Petrol Pump NH...        ₹3659
#
#   Offer Percentage  Price        Ratings     Review
# ...

# %%
somnath= {
    'https://www.oyorooms.com/hotels-in-somnath/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in somnath:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'somnath',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
somnath = pd.DataFrame(all_data)

# Display the DataFrame
somnath
# Out:
#      Place                                  Hotel Name  \
# 0  somnath  Super Collection O Veraval Railway Station
# 1  somnath                       Super Hotel O Somnath
#
#                     Destination Actual Price Offer Percentage  Price  \
# 0              Veraval, Somnath        ₹2846          72% off   ₹615
# 1  Near Somnath Temple, Somnath        ₹5928          72% off  ₹1361
#
#          Ratings     Review
# 0  (101 Ratings)  Excellent
# 1  (109 Ratings)   Fabulous

# %%
srinagar= {
    'https://www.oyorooms.com/hotels-in-srinagar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in srinagar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'srinagar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
srinagar = pd.DataFrame(all_data)

# Display the DataFrame
srinagar
# Out:
#        Place                                         Hotel Name  \
# 0   srinagar                   Collection O Airport Road Solina
# 1   srinagar                    Hotel O Residency Road Srinagar
# 2   srinagar            Townhouse Rajbagh formerly Hotel Modern
# 3   srinagar  Super Hotel O Zero Bridge formerly New Time Star
# 4   srinagar                    Super Collection O Brein Nishat
# 5   srinagar                               Collection O Rajbagh
# 6   srinagar                        Super Collection O Dal Lake
# 7   srinagar                             Hotel O Arcadian Idyll
# 8   srinagar                        Super Hotel O Abc Residency
# 9   srinagar                               Hotel O Lit Homestay
# 10  srinagar         Hotel O THE HOTEL Oshin Hotel & Restaurant
# 11  srinagar                  Hotel O 84461 Hotel Shaani Resort
# 12  srinagar                       Hotel O POP Foreshore Resort
# 13  srinagar                            Hotel O Hunter's & Cafe
# ...

# %%
surat= {
    'https://www.oyorooms.com/hotels-in-surat/?page=2',
    'https://www.oyorooms.com/hotels-in-surat/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in surat:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'surat',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
surat = pd.DataFrame(all_data)

# Display the DataFrame
surat
# Out:
#     Place                                         Hotel Name  \
# 0   surat                               Hotel O Jack Sparrow
# 1   surat                                    Townhouse Lotus
# 2   surat                                     Hotel O Galaxy
# 3   surat                                 Hotel O Cozy Rooms
# 4   surat                                   Hotel O Infinity
# 5   surat                        Collection O De'pearl Hotel
# 6   surat                                      Hotel O Lotus
# 7   surat                              Hotel O Enclave Rooms
# 8   surat                             Hotel O 7 Square Hotel
# 9   surat                                 Hotel O Secure Inn
# 10  surat                         Collection O Infini Palace
# 11  surat                                        Hotel O Max
# 12  surat                                Hotel O Ripple Mall
# 13  surat                              Hotel O luxurious inn
# ...

# %%
tarapith= {
    'https://www.oyorooms.com/hotels-in-tarapith/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in tarapith:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'tarapith',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
tarapith = pd.DataFrame(all_data)

# Display the DataFrame
tarapith
# Out:
#       Place               Hotel Name  \
# 0  tarapith             Hotel O Sonu
# 1  tarapith    Hotel O Kalyani Lodge
# 2  tarapith     Hotel O Yuvraj Lodge
# 3  tarapith           Agnibina Lodge
# 4  tarapith  Hotel O Bideshini Hotel
#
#                                  Destination Actual Price Offer Percentage  \
# 0         Tarapith Temple Road, Tarapith, WB        ₹6072          72% off
# 1                Near PNB Bank ATM, Tarapith        ₹4372          72% off
# 2  G-0G-0Tarapith - Rampurhat Road, Tarapith        ₹5785          72% off
# 3        Tarapith mundomalini tala, Tarapith        ₹4731          71% off
# 4        Near Tarapith Temple Road, Tarapith        ₹5817          72% off
#
#    Price        Ratings     Review
# 0  ₹1416  (156 Ratings)       Fair
# 1   ₹992   (13 Ratings)  Very Good
# 2  ₹1340    (6 Ratings)       Good
# 3  ₹1090    (1 Ratings)   Fabulous
# 4  ₹1335    (5 Ratings)       Fair

# %%
tehri= {
    'https://www.oyorooms.com/hotels-in-tehri/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in tehri:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'tehri',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
tehri = pd.DataFrame(all_data)

# Display the DataFrame
tehri
# Out:
#    Place                      Hotel Name                         Destination  \
# 0  tehri  SPOT ON Hotel Kamand Residency                       Kamand, Tehri
# 1  tehri         Collection O Bhagirathi  Near Bus Stand, Baurari, New Tehri
#
#   Actual Price Offer Percentage  Price      Ratings     Review
# 0        ₹7415          72% off  ₹1731  (1 Ratings)  Very Good
# 1        ₹7422          71% off  ₹1784  (1 Ratings)   Fabulous

# %%
thekkady= {
    'https://www.oyorooms.com/hotels-in-thekkady/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in thekkady:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'thekkady',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
thekkady = pd.DataFrame(all_data)

# Display the DataFrame
thekkady
# Out:
#       Place                     Hotel Name  \
# 0  thekkady              Hotel O Kattapana
# 1  thekkady    Hotel O Ceasar Palace Annex
# 2  thekkady      Townhouse Edassery Resort
# 3  thekkady  Hotel O Valley View Residency
# 4  thekkady    Hotel O Green Fort Thekkady
#
#                                    Destination Actual Price Offer Percentage  \
# 0                          Kattapana, Thekkady        ₹3483          74% off
# 1                            Idukki., Thekkady        ₹5381          71% off
# 2  Near Boi, Kumily - Puliyanmala Rd, Thekkady        ₹5104          68% off
# 3                            Vagamon, Thekkady        ₹5949          72% off
# 4                      India -685509, Thekkady       ₹12579          74% off
#
#    Price        Ratings     Review
# 0   ₹704   (94 Ratings)  Excellent
# 1  ₹1231  (108 Ratings)       Good
# 2  ₹1315   (41 Ratings)  Very Good
# 3  ₹1379    (1 Ratings)  Very Good
# 4  ₹2715    (1 Ratings)   Fabulous

# %%
thrissur= {
    'https://www.oyorooms.com/hotels-in-thrissur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in thrissur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'thrissur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
thrissur = pd.DataFrame(all_data)

# Display the DataFrame
thrissur
# Out:
#       Place                                         Hotel Name  \
# 0  thrissur  Super Hotel O Thrissur Near Thrissur Medical C...
# 1  thrissur                     Super Hotel O Sree Badra Lodge
# 2  thrissur                 Super Collection O Viyyur Thrissur
# 3  thrissur                 Hotel O Victoria Hotels & Resorts
# 4  thrissur                                  Hotel O Rose Home
# 5  thrissur                      Capital O Kovilakam Residency
# 6  thrissur                        SPOT ON Hotel Libra Regency
# 7  thrissur                      Collection O Chalakudy Hotels
#
#                                          Destination Actual Price  \
# 0                              Peringandur, Thrissur        ₹3789
# 1  Landmark- Health University Medical Collage, T...        ₹3178
# 2                           Ramavarmapuram, Thrissur        ₹5224
# 3                                Chalakudy, Thrissur        ₹5384
# 4                                 Velapaya, Thrissur        ₹4853
# ...

# %%
tirupati= {
    'https://www.oyorooms.com/hotels-in-tirupati/?page=2',
    'https://www.oyorooms.com/hotels-in-tirupati/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in tirupati:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'tirupati',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
tirupati = pd.DataFrame(all_data)

# Display the DataFrame
tirupati
# Out:
#        Place                                         Hotel Name  \
# 0   tirupati                              Hotel O VLR Residency
# 1   tirupati                              Hotel O PVS Home Stay
# 2   tirupati                                            V M Inn
# 3   tirupati                       Collection O Seven Hills Inn
# 4   tirupati                     Collection O Poojith Residency
# 5   tirupati                               Hotel O New Aiswarya
# 6   tirupati                   Collection O New Balaji Homestay
# 7   tirupati                              Hotel O SR RESIDENCY
# 8   tirupati                  Collection O Ns Service Apartment
# 9   tirupati                  Townhouse OAK Hotel Grand Orchid
# 10  tirupati                                 Hotel O ELITE PARK
# 11  tirupati                      Hotel O SRI BALAJI HOME STAYS
# 12  tirupati                              Hotel O PS5 Home Stay
# 13  tirupati                   Collection O Hotel Bloom Orchid
# ...

# %%
tiruppur= {
    'https://www.oyorooms.com/hotels-in-tiruppur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in tiruppur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'tiruppur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
tiruppur = pd.DataFrame(all_data)

# Display the DataFrame
tiruppur
# Out:
#       Place                                   Hotel Name  \
# 0  tiruppur            Collection O Palladam City Center
# 1  tiruppur  Super Hotel O Tiruppur Near Railway station
# 2  tiruppur                               Hotel O JK INN
#
#                                        Destination Actual Price  \
# 0                               Palladam, Tiruppur        ₹3261
# 1  Near Old Poothar Theatre, Masco nagar, Tiruppur        ₹4459
# 2                          Avinashi Road, Tiruppur        ₹3465
#
#   Offer Percentage  Price        Ratings     Review
# 0          77% off   ₹567   (21 Ratings)   Fabulous
# 1          68% off  ₹1177  (908 Ratings)  Excellent
# 2          72% off   ₹785   (57 Ratings)       Fair

# %%
trichy= {
    'https://www.oyorooms.com/hotels-in-trichy/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in trichy:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'trichy',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
trichy = pd.DataFrame(all_data)

# Display the DataFrame
trichy
# Out:
#     Place                Hotel Name  \
# 0  trichy  Hotel O Annai Residency
# 1  trichy    IBRAS Residency Trichy
# 2  trichy    Hotel O MALA RESIDENCY
# 3  trichy     Hotel O Rainbow Stays
# 4  trichy   Super Hotel O Am Grandd
#
#                                          Destination Actual Price  \
# 0                                   Uraiyoor, Trichy        ₹3851
# 1                          Chatram Bus stand, Trichy        ₹4354
# 2                                 Manapparai, Trichy        ₹5142
# 3                  Near Rockfort Theppakulam, Trichy        ₹2912
# 4  No 9/5, Appsara Complex,Melapudur,Madurai Road...        ₹5534
#
#   Offer Percentage  Price         Ratings    Review
# 0          72% off   ₹881     (7 Ratings)      Good
# 1          72% off  ₹1000     (8 Ratings)      Good
# 2          72% off  ₹1175    (89 Ratings)      Fair
# 3          78% off   ₹494  (2054 Ratings)  Fabulous
# 4          68% off  ₹1429              NA        NA

# %%
trivandrum= {
    'https://www.oyorooms.com/hotels-in-trivandrum/?page=2',
    'https://www.oyorooms.com/hotels-in-trivandrum/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in trivandrum:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'trivandrum',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
trivandrum = pd.DataFrame(all_data)

# Display the DataFrame
trivandrum
# Out:
#          Place                                         Hotel Name  \
# 0   trivandrum                            Super Hotel O East Fort
# 1   trivandrum  Super Collection O Chalai Bazaar Near Railway ...
# 2   trivandrum  Super Townhouse MG Road Trivandrum formerly Na...
# 3   trivandrum                           Collection O Thampampoor
# 4   trivandrum  Super Hotel O Attukal Near Attakulangara forme...
# 5   trivandrum                       SPOT ON The New View Regency
# 6   trivandrum                   Super Collection O Golden Avenue
# 7   trivandrum                      Super Townhouse Prince Palace
# 8   trivandrum                             THE NEW VIEW HOTEL INN
# 9   trivandrum                          Hotel O NILA TOURIST HOME
# 10  trivandrum                                    Hotel O Skywind
# 11  trivandrum                              Hotel O THE HOME SPOT
# 12  trivandrum              Collection O Lefort LUXE by PopTavern
# ...

# %%
udaipur= {
    'https://www.oyorooms.com/hotels-in-udaipur/?page=2',
    'https://www.oyorooms.com/hotels-in-udaipur/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in udaipur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'udaipur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
udaipur = pd.DataFrame(all_data)

# Display the DataFrame
udaipur
# Out:
#       Place                                         Hotel Name  \
# 0   udaipur                      Collection O Lake Palace Road
# 1   udaipur            Hotel O Shree Balaji Hotel & Restaurant
# 2   udaipur    Super Townhouse Fateh Sagar formerly Vatika Inn
# 3   udaipur                                  Hotel O Sector 14
# 4   udaipur  Super Collection O Paras Circle formerly Oshee...
# 5   udaipur  Hotel O Sector 14 Udaipur formerly Hotel Mansi...
# 6   udaipur                 Hotel O 80568D The Chamunda Palace
# 7   udaipur                       Hotel O Sector 6 Hiran Magri
# 8   udaipur           Super Townhouse Pichola formerly Vinayak
# 9   udaipur                               Hotel O Shree Palace
# 10  udaipur                    Hotel O 826019 Hotel Sandal inn
# 11  udaipur                            Hotel O Goverdhan Villa
# 12  udaipur                             Collection O Greenland
# 13  udaipur              Palette Shikarbadi formerly Belle Vue
# ...

# %%
udupi_manipal= {
    'https://www.oyorooms.com/hotels-in-udupi_manipal/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in udupi_manipal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'udupi_manipal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
udupi_manipal = pd.DataFrame(all_data)

# Display the DataFrame
udupi_manipal
# Out:
#            Place                      Hotel Name  \
# 0  udupi_manipal            Hotel O Silver House
# 1  udupi_manipal  Collection O Venky''s Stay Inn
#
#                                          Destination Actual Price  \
# 0  Near Mangala layout, Dasharath Nagar, Udupi-Ma...        ₹4734
# 1             Behind Kalyan Jewellers, Udupi-Manipal        ₹7038
#
#   Offer Percentage  Price        Ratings     Review
# 0          71% off  ₹1091   (38 Ratings)       Good
# 1          68% off  ₹1814  (140 Ratings)  Very Good

# %%
ujjain= {
    'https://www.oyorooms.com/hotels-in-ujjain/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in ujjain:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'ujjain',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
ujjain = pd.DataFrame(all_data)

# Display the DataFrame
ujjain
# Out:
#      Place                                         Hotel Name  \
# 0   ujjain  Super Hotel O Hanuman Naka Ujjain formerly Kri...
# 1   ujjain  Collection O Ujjain City Centre formerly Hotel...
# 2   ujjain                 Super Hotel O Tower Chowk Freeganj
# 3   ujjain                             Hotel O Mahakal Temple
# 4   ujjain                     Hotel O Ujjain Near Hari Fatak
# 5   ujjain                             Super Hotel O Divyalok
# 6   ujjain                       Hotel O Shikar Avenue Ujjain
# 7   ujjain                                Hotel O Apna Palace
# 8   ujjain                                         Hotel O Om
# 9   ujjain                                   Hotel O Trinetra
# 10  ujjain                    Hotel O SDF Hotel And Home Stay
# 11  ujjain                       Hotel O SDF Hotel Shree Deep
# 12  ujjain                               Hotel O Singh Palace
# 13  ujjain                  Super Collection O Mahakal Ujjain
#
# ...

# %%
vadodara= {
    'https://www.oyorooms.com/hotels-in-vadodara/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vadodara:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vadodara',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vadodara = pd.DataFrame(all_data)

# Display the DataFrame
vadodara
# Out:
#        Place                      Hotel Name  \
# 0   vadodara   SPOT ON Krishna Hotel & Rooms
# 1   vadodara           Sunday Hotel Vadodara
# 2   vadodara                 Townhouse Tulip
# 3   vadodara           SPOT ON Hotel Hilltop
# 4   vadodara             Hotel O Tulsi Hotel
# 5   vadodara                  Hotel O Ambika
# 6   vadodara                  Hotel O Shivam
# 7   vadodara                  Hotel O Aagman
# 8   vadodara  Collection O Sujay Hospitality
# 9   vadodara         Collection O Raj Palace
# 10  vadodara               Hotel O Shiv Kunj
# 11  vadodara           OYO 79733 Hotel Shiva
# 12  vadodara                 Hotel O Sunrise
# 13  vadodara      Collection O Riddhi Siddhi
# 14  vadodara          Collection O Ace Grand
# 15  vadodara          Collection O SKY Hills
# 16  vadodara               Hotel O Hill View
# 17  vadodara         Collection O Lotus Gold
# 18  vadodara        Clubhouse Hotel Raajpath
# 19  vadodara                  Hotel O Atithi
#
# ...

# %%
varanasi= {
    'https://www.oyorooms.com/hotels-in-varanasi/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in varanasi:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'varanasi',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
varanasi = pd.DataFrame(all_data)

# Display the DataFrame
varanasi
# Out:
#        Place                                 Hotel Name  \
# 0   varanasi                SPOT ON Sukanya Guest House
# 1   varanasi                      Hotel O Pramod Garden
# 2   varanasi   Collection O Kewal Palace Hyderabad Gate
# 3   varanasi               Collection O Maharaja Resort
# 4   varanasi                       Hotel O Us Residency
# 5   varanasi  Hotel O Saanvi Residency Inn a Ganga View
# 6   varanasi                       Hotel O Sparrow Nest
# 7   varanasi                  Hotel O Shiv Kashi Palace
# 8   varanasi       Hotel O Flagship Adbhut Moment Hotel
# 9   varanasi                        Hotel O J.D. Palace
# 10  varanasi                        Hotel O Kriti Green
# 11  varanasi                Hotel O Shubh Kashi Palace
# 12  varanasi                    Hotel O Kiran Home Stay
# 13  varanasi                         Hotel O JSB Palace
# 14  varanasi               Hotel O National Banaras inn
# 15  varanasi                                Hotel O JMD
# ...

# %%
vellore= {
    'https://www.oyorooms.com/hotels-in-vellore/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vellore:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vellore',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vellore = pd.DataFrame(all_data)

# Display the DataFrame
vellore
# Out:
#      Place                                        Hotel Name  \
# 0  vellore                    Super Hotel O VIT Road Vellore
# 1  vellore  Hotel O Katpadi Vellore formerly Leo's Home Stay
# 2  vellore                 Super Hotel O Poigai Near Airport
# 3  vellore                          Hotel O Prince Residency
# 4  vellore    Hotel O Ranipet Vellore formerly Ars Residency
# 5  vellore                              Hotel O Rj Royal Inn
#
#                                    Destination Actual Price Offer Percentage  \
# 0                             Katpadi, Vellore        ₹3014          72% off
# 1    Near Amma Children park, Katpadi, Vellore        ₹3022          71% off
# 2                             Latteri, Vellore        ₹4367          71% off
# 3  Near Old Bus Stand, Sitting Bazaar, Vellore        ₹2734          72% off
# 4       Near KH Shoe Flyover, Ranipet, Vellore        ₹2062          74% off
# ...

# %%
vijayawada= {
    'https://www.oyorooms.com/hotels-in-vijayawada/?page=3',
    'https://www.oyorooms.com/hotels-in-vijayawada/?page=2',
    'https://www.oyorooms.com/hotels-in-vijayawada/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vijayawada:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vijayawada',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vijayawada = pd.DataFrame(all_data)

# Display the DataFrame
vijayawada
# Out:
#          Place                                       Hotel Name  \
# 0   vijayawada                        Capital O Siddartha Grand
# 1   vijayawada                            Hotel O anu residency
# 2   vijayawada                           Super Hotel O CJ Pride
# 3   vijayawada                    Super Collection O KEYS ELITE
# 4   vijayawada                             Hotel O Happy Hotels
# 5   vijayawada                                Hotel O Y2  Grand
# 6   vijayawada                           Collection O Kk Trends
# 7   vijayawada             Super Collection O THE CAPITAL HOTEL
# 8   vijayawada                             Hotel O Sr Residency
# 9   vijayawada                                   Capital O Alfa
# 10  vijayawada                        Super Hotel O Sai Capital
# 11  vijayawada                         Capital O Pratibha Grand
# 12  vijayawada                        Hotel O Happy Grand Hotel
# 13  vijayawada                              Hotel O Dev Krishna
# ...

# %%
virudhunagar= {
    'https://www.oyorooms.com/hotels-in-virudhunagar/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in virudhunagar:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'virudhunagar',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
virudhunagar = pd.DataFrame(all_data)

# Display the DataFrame
virudhunagar
# Out:
#           Place                                        Hotel Name  \
# 0  virudhunagar  Collection O SRI Lakshmi Residency And Mahal A/C
#
#                     Destination Actual Price Offer Percentage  Price Ratings  \
# 0  Srivilliputhur, Virudhunagar        ₹7722          72% off  ₹1800      NA
#
#   Review
# 0     NA

# %%
visakhapatnam= {
    'https://www.oyorooms.com/hotels-in-visakhapatnam/?page=3',
    'https://www.oyorooms.com/hotels-in-visakhapatnam/?page=2',
    'https://www.oyorooms.com/hotels-in-visakhapatnam/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in visakhapatnam:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'visakhapatnam',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
visakhapatnam = pd.DataFrame(all_data)

# Display the DataFrame
visakhapatnam
# Out:
#             Place                                         Hotel Name  \
# 0   visakhapatnam                       Hotel O A1 Premium AC Rooms
# 1   visakhapatnam                 Townhouse OAK Vibe Vacation Hotels
# 2   visakhapatnam                              SPOT ON SGS RESIDENCY
# 3   visakhapatnam                                  Hotel O Millennia
# 4   visakhapatnam                                    Hotel O Cauvery
# 5   visakhapatnam                        Hotel O Adaaran Ocean Homes
# 6   visakhapatnam                          Super Townhouse RCC Lamps
# 7   visakhapatnam                          SPOT ON Grand Mantralayam
# 8   visakhapatnam                              Hotel O VRK Residency
# 9   visakhapatnam                             Hotel O MID-TOWN LODGE
# 10  visakhapatnam                   Hotel O 80823 Hotel Sitara Grand
# 11  visakhapatnam       Super Hotel O Allipuram Near Railway Station
# 12  visakhapatnam                                  Capital O Seatree
# ...

# %%
vitthalapur= {
    'https://www.oyorooms.com/hotels-in-vitthalapur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vitthalapur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vitthalapur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vitthalapur = pd.DataFrame(all_data)

# Display the DataFrame
vitthalapur
# Out:
#          Place                                   Hotel Name  \
# 0  vitthalapur  Hotel O Vitthalapur formerly Vitthal Palace
#
#                                          Destination Actual Price  \
# 0  Above GIDC Vitthalapur-Kadi, Vitthalapur, Mehsana        ₹2504
#
#   Offer Percentage Price       Ratings     Review
# 0          68% off  ₹615  (12 Ratings)  Excellent

# %%
vizianagaram= {
    'https://www.oyorooms.com/hotels-in-vizianagaram/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vizianagaram:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vizianagaram',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vizianagaram = pd.DataFrame(all_data)

# Display the DataFrame
vizianagaram
# Out:
#           Place                                       Hotel Name  \
# 0  vizianagaram  Super Hotel O Vizianagaram Near Railway Station
#
#                        Destination Actual Price Offer Percentage  Price  \
# 0  Beside Lions Club, Vizianagaram        ₹4347          68% off  ₹1148
#
#          Ratings     Review
# 0  (465 Ratings)  Excellent

# %%
vrindavan= {
    'https://www.oyorooms.com/hotels-in-vrindavan/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in vrindavan:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'vrindavan',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
vrindavan = pd.DataFrame(all_data)

# Display the DataFrame
vrindavan
# Out:
#        Place                                         Hotel Name  \
# 0  vrindavan  Hotel O Chahtikara Chowk Vrindavan formerly La...
# 1  vrindavan  Super Hotel O Sunrakh Road Vrindavan formerly ...
# 2  vrindavan            Hotel O Shree Ji Puram Near Prem Mandir
# 3  vrindavan                          Hotel O BRAJ HERITAGE INN
# 4  vrindavan                           Hotel O Vrinda Residency
# 5  vrindavan                           Hotel O Krishna Cottage
# 6  vrindavan                             Hotel O Golden Palace
#
#                                          Destination Actual Price  \
# 0                            Janam Bhoomi, Vrindavan        ₹4767
# 1                            Sunrakh Road, Vrindavan        ₹5059
# 2                      Near Shikar Mandir, Vrindavan        ₹4144
# 3                                   Omaxe, Vrindavan        ₹5182
# 4           Near Prem Mandir,Rukmani ViHar,Vrindavan        ₹4368
# ...

# %%
warangal= {
    'https://www.oyorooms.com/hotels-in-warangal/?page=2',
    'https://www.oyorooms.com/hotels-in-warangal/?page=1'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in warangal:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'warangal',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
warangal = pd.DataFrame(all_data)

# Display the DataFrame
warangal
# Out:
#        Place                              Hotel Name  \
# 0   warangal                 Hotel O Suraj Residency
# 1   warangal                        Hotel O R Square
# 2   warangal           Hotel O Raghavendra Residency
# 3   warangal                Hotel O VRR LUXURY HOTEL
# 4   warangal                        Hotel O R Square
# 5   warangal                           Hotel O Ragas
# 6   warangal   Super Collection O Bommarilu Warangal
# 7   warangal                Hotel O Sky luxury rooms
# 8   warangal           SPOT ON SRI KARTHIK GRAND INN
# 9   warangal  Super Collection O Hanamkonda Near NIT
# 10  warangal                 Hotel O Moonlight Grand
# 11  warangal            Hotel O Sai Ganesh Residency
# 12  warangal              Super Townhouse Casa Grand
# 13  warangal             Hotel O LAHARI LUXURY ROOMS
# 14  warangal                         Hotel O Raj Inn
# 15  warangal               Hotel O Lakshmi Royal Inn
# 16  warangal                        Hotel O Star Inn
# ...

# %%
wardha= {
    'https://www.oyorooms.com/hotels-in-wardha/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in wardha:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'wardha',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
wardha = pd.DataFrame(all_data)

# Display the DataFrame
wardha
# Out:
#     Place                    Hotel Name  \
# 0  wardha          SPOT ON Hotel Ashoka
# 1  wardha  SPOT ON SANGAM PALACE RESORT
# 2  wardha           SARANSH R RESIDENCY
#
#                                          Destination Actual Price  \
# 0  Hotal Ashoka Aarvi Road Near Pipri College Dau...        ₹2720
# 1                  Near Padegaon Bridge.null, Wardha        ₹1941
# 2                                     Wardha, Wardha        ₹2912
#
#   Offer Percentage Price       Ratings     Review
# 0          82% off  ₹382  (21 Ratings)  Very Good
# 1          49% off  ₹824   (2 Ratings)       Fair
# 2          70% off  ₹735            NA         NA

# %%
wayanad= {
    'https://www.oyorooms.com/hotels-in-wayanad/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in wayanad:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'wayanad',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
wayanad = pd.DataFrame(all_data)

# Display the DataFrame
wayanad
# Out:
#      Place                                        Hotel Name  \
# 0  wayanad  Super Hotel O Sultan Bathery formerly Bluevalley
# 1  wayanad               Super Collection O Kalpetta Wayanad
# 2  wayanad                   Super Hotel O Panamaram Wayanad
# 3  wayanad         Hotel O Home Elegant Stay Fine Nest Homes
# 4  wayanad                        Hotel O Aiswarya Residency
# 5  wayanad                       SPOT ON Prarthana Residency
# 6  wayanad                             Hotel O Yayaz Resorts
# 7  wayanad                        Hotel O Blue Sky Apartment
# 8  wayanad                            Hotel O Hill Way Rooms
# 9  wayanad                       Collection O Wayanad Square
#
#                            Destination Actual Price Offer Percentage  Price  \
# 0  Kalluvayal, Sultan Bathery, Wayanad        ₹3470          76% off   ₹676
# 1                    Kalpetta, Wayanad        ₹4507          68% off  ₹1190
# ...

# %%
yercaud= {
    'https://www.oyorooms.com/hotels-in-yercaud/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in yercaud:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'yercaud',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
yercaud = pd.DataFrame(all_data)

# Display the DataFrame
yercaud
# Out:
#      Place                                    Hotel Name     Destination  \
# 0  yercaud  Palette - Coastal Grand Anglo French Resorts  India, Yercaud
#
#   Actual Price Offer Percentage  Price       Ratings     Review
# 0       ₹10834          67% off  ₹2989  (10 Ratings)  Very Good

# %%
zirakpur= {
    'https://www.oyorooms.com/hotels-in-zirakpur/'
}

# Initialize an empty DataFrame to store results
all_data = []

# Iterate over each URL and scrape data
for url in zirakpur:
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        sels = Selector(text=response.text)
        place = sels.css('h1.ListingContentHeader__h1::text').getall()
        hotelname = sels.css('h3.listingHotelDescription__hotelName.d-textEllipsis::text').getall()
        destination = sels.css('span.u-line--clamp-2::text').getall()
        ratings = sels.css('span.hotelRating__ratingSummary.hotelRating__rating--clickable::text').getall()
        comment = sels.css('span.hotelRating__ratingSummary::text').getall()[1::2]
        offered_price = sels.css('span.listingPrice__finalPrice.listingPrice__finalPrice--black::text').getall()
        offer_percentage = sels.css('span.listingPrice__percentage::text').getall()
        actual_price = sels.css('span.listingPrice__slashedPrice.d-body-lg::text').getall()
        
        # Pad lists to equal length
        max_length = max(len(hotelname), len(destination), len(ratings), len(comment), len(offered_price), len(offer_percentage), len(actual_price))
        place = place + ['NA'] * (max_length - len(place))
        hotelname = hotelname + ['NA'] * (max_length - len(hotelname))
        destination = destination + ['NA'] * (max_length - len(destination))
        ratings = ratings + ['NA'] * (max_length - len(ratings))
        comment = comment + ['NA'] * (max_length - len(comment))
        offered_price = offered_price + ['NA'] * (max_length - len(offered_price))
        offer_percentage = offer_percentage + ['NA'] * (max_length - len(offer_percentage))
        actual_price = actual_price + ['NA'] * (max_length - len(actual_price))
        
        # Append data for this page to the list
        for i in range(max_length):
            all_data.append({
                'Place': 'zirakpur',
                'Hotel Name': hotelname[i],
                'Destination': destination[i],
                'Actual Price': actual_price[i],
                'Offer Percentage': offer_percentage[i],
                'Price': offered_price[i],
                'Ratings': ratings[i],
                'Review': comment[i]
            })

# Convert the list of dictionaries to a DataFrame
zirakpur = pd.DataFrame(all_data)

# Display the DataFrame
zirakpur
# Out:
#        Place                                         Hotel Name  \
# 0   zirakpur        Hotel O Royal Zirakpur Formerly Royal woods
# 1   zirakpur  Super Hotel O Lohgarh Road Zirakpur formerly J...
# 2   zirakpur               Super Townhouse Eden Garden Zirakpur
# 3   zirakpur  Super Townhouse Eastern View formerly Vihaan R...
# 4   zirakpur  Super Hotel O Chandigarh Highway Near Prabhat ...
# 5   zirakpur                                 Hotel O Food Plaza
# 6   zirakpur                          Hotel O Tricity Relax Inn
# 7   zirakpur                        Hotel O 807358 Hotel Shivam
# 8   zirakpur                     Collection O Citi Inn Zirakpur
# 9   zirakpur                                 Collection O Ignis
# 10  zirakpur                                Collection O Athens
# 11  zirakpur                                        Hotel Wasat
# 12  zirakpur                                     Hotel O Elista
# 13  zirakpur                             Hotel O AV Continental
# ...

# %%
oyo=[agra,ahmedabad,ajmer,aligarh,alwar,ambala,amritsar,asansol,aurangabad,ayodhya,bangalore,bareilly,barpeta,bathinda,bawal,berhampore,bhilai,bhiwadi,bhubaneswar,bhopal,bijnor,bilaspur,bodhgaya,bulandshahr,calicut,chandigarh,chennai,coimbatore,coorg,cuttack,dehradun,delhi,delhi_transit,deoghar,dhanbad,dharamshala,digha,durgapur,ernakulam,erode,faridaba,gangtok,gaya,ghaziabad,goa,gorakhpur,guntur,gurgaon,guwahati,guntur,gurgaon,guwahati,gwalior,haridwar,hisar,hyderabad,indore,jabalpur,jaipur,jalandhar,jammu,jamshedpur,jodhpur,kakinada,kalimpong,kannur,kanpur,kanyakumari,karnal,katra,khammam,kochi,kodaikanal,kolkata,kollam,kota,kovalam,kurukshetra,latur,lucknow,ludhiana,madurai,mahabaleshwar,mahabalipuram,manali,mandarmoni,manesar,mangalore,mathura,mcleod_ganj,meerut,mohali,moradabad,motihari,mumbai,mussoorie,mysore,nagpur,namakkal,narnaul,nashik,navi_mumbai,noida,ooty,pachmarhi,pathanamthitta,patiala,patna,pondicherry,blair,pune,puri,raipur,rajahmundry,rajkot,ranchi,rewari,rishikesh,rohtak,salem,satna,shillong,shimla,shirdi,siliguri,sirsa,sitapur,somnath,srinagar,surat,tarapith,tirupati,tehri,thekkady,thrissur,tirupati,tiruppur,trichy,trivandrum,udaipur,udupi_manipal,ujjain,vadodara,varanasi,vellore,vijayawada,virudhunagar,visakhapatnam,vitthalapur,vizianagaram,vrindavan,warangal,wardha,wayanad,yercaud,zirakpur]

# %%
oyo=pd.concat(oyo)

# %%
oyo.to_csv('hotels_oyo.csv')
